# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# ___
#
# <a href="https://lms.clarusway.com/mod/lesson/view.php?id=8511&pageid=8142&startlastseen=no"><img align="left" src="https://i.ibb.co/6Z5pQxD/lmss.png" alt="Open in Clarusway LMS" width="70" height="200" title="Open Clarusway Learning Management Sytem"></a>
#
# <a href=""><img align="right" src="https://i.ibb.co/n3HWyQX/github-logo.png" alt="Open in Clarusway GitHub" width="100" height="150" title="Open and Execute in Clarusway GitHub Repository"></a>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <img src=https://i.ibb.co/74fKh51/RFM-Analysis-banner.jpg width="1100" height="100">
#
# [Image Credit](https://www.notifyvisitors.com/blog/rfm-analysis/)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# # <p style="background-color:#9452a5;font-family:newtimeroman;color:#FFF9ED;font-size:135|%;text-align:center;border-radius:10px 10px;">RFM ANALYSIS, CUSTOMER SEGMENTATION, & COHORT ANALYSIS</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <h3 style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;" class="list-group-item list-group-item-action active" data-toggle="list" role="tablist" aria-controls="home">TABLE OF CONTENTS</h3>
#
# * [   PREFACE](#0)
# * [1) DATA](#1)
#     * [1.1 Context](#1.1)
#     * [1.2 About the Features](#1.2)
#     * [1.3 What is the Problem?](#1.3)
#     * [1.4 Project Structure in General](#1.4)
#     * [1.5 What is RFM & Cohort Analysis](#1.5)
#     * [1.6 Tasks in the Analysis](#1.6)
# * [2) LIBRARIES NEEDED IN THE STUDY](#2)
#     * [2.1 User Defined Functions](#2.1)
# * [3) ANALYSIS](#3)
#     * [3.1) Reading the Data](#3)
# * [4) EXPLORATORY DATA ANALYSIS (EDA) & VISUALIZATION](#4)
#     * [4.1 - A General Look at the Data](#4.1)
#     * [4.2 - The Tasks in This Section](#4.2)
# * [5) RFM ANALYSIS](#5)
#     * [5.1 - The Tasks in This Section](#5.1)
# * [6 - CUSTOMER SEGMENTATION WITH RFM SCORES](#6)
#     * [6.1 Calculating RFM Scoring](#6.1)
#     * [6.2 Plotting RFM Segments](#6.2)
# * [7 - CREATING COHORTS & CONDUCTING COHORT ANALYSIS](#7)
#
# **📢 SPECIAL NOTE: There may be some additional sub-tasks associated with each task. If you want, you can create and follow your own framework/workflow during the course of the work.**
# * [8) CONLUSION](#8)
# * [9) REFERENCES](#9)
# * [10) FURTHER READINGS](#10)

# %% [markdown]
# <a id="0"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">PREFACE</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the final (Capstone) Project to complete the Data Analytics Module, where you have go through different scenarios and projects so far.
#
# This is a project in which you will learn what is RFM? and how to apply your Data Analytics skills for RFM Analysis and Customer Segmentation using approaches and methods/functions you have learned so far. Besides, you will remember and improve the Data Cleaning, Data Visualization, and Exploratory Data Analysis capabilities you have learned along the way course. On the other hand, you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This project assumes that you already know the basics of coding in Python and are familiar with the methods/functions in Pandas.
#
# **Usefull Links for a better understanding and more information, please refer to;**<br>
# 🧐 **[Link 1](https://medium.com/machine-learning-t%C3%BCrkiye/crm-analizi-rfm-analizi-ve-cltv-m%C3%BC%C5%9Fteri-ya%C5%9Fam-boyu-de%C4%9Feri-36e5c3a232b1) (in Turkish), [Link 2](https://medium.com/capillary-data-science/rfm-analysis-an-effective-customer-segmentation-technique-using-python-58804480d232), [Link 3](https://towardsdatascience.com/rfm-analysis-using-bigquery-ml-bfaa51b83086), [Link 4](https://www.ticimax.com/blog/kohort-analizi-hakkinda-bilmeniz-gerekenler) (in Turkish) & [Link 5](https://www.ibm.com/docs/en/spss-modeler/18.2.2?topic=node-rfm-analysis-settings)**

# %% [markdown]
# <a id="1"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">1 - DATA</p>
#
# <a id="1.1"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">1.1 Context</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>
#
#
# In this project, the **🧐[Online Retail dataset](https://archive.ics.uci.edu/dataset/352/online+retail)** from the ``UCI Machine Learning Repository`` is used for ***Exploratory Data Analysis (EDA)***, ***RFM Analysis***, and ***Cohort Analysis*** so that you will, in general, analyze all relevant customer behaviors in dataset, segment these customers based on their Recency, Frequency, and Monotary scores, and in the end be able to predict the behaviors to retain customers and help decision-makers develop focused customer retention programs.
#
# "This is a transnational dataset which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers."
#
# **For a better understanding and more information, please refer to 📝 [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Online+Retail) and 📝 [Kaggle Website](https://www.kaggle.com/vijayuv/onlineretail)**
#
# **📢 SPECIAL NOTE: 👉Based on the Domain Knowledge below, this dataset will be modified by adding such features as ``age``, ``gender``, and ``income`` to conduct a more comprehensive Exploratory Data Analysis-EDA.**
#
# **🧐 [Average UK salary by age](https://occaminvesting.co.uk/average-uk-salary-by-age/)**<br>
# **🧐 [What Is the Average UK Salary by Industry, Age and Education?](https://uk.indeed.com/career-advice/pay-salary/average-uk-salary)**<br>
# **🧐 [Median annual earnings for full-time employees in the United Kingdom in 2022, by age and gender](https://www.statista.com/statistics/802183/annual-pay-employees-in-the-uk/)**<br>

# %% [markdown]
# <a id="1.2"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">1.2 About The Features</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#e9a1ed" data-toggle="popover">Table of Contents</a>
#
# **Each row in the dataset represents a customer, each column contains customer’s attributes or demographic characteristics and the information about their transactions.The features in the given dataset are:**
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.

# %% [markdown]
# <a id="1.3"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">1.3 What is the Problem? (Hints about the Structure of the Study)</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#e9a1ed" data-toggle="popover">Table of Contents</a>
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK **NOT** only has the most sales revenue, but also the most customers. So you will most probably decide to continue to analyze only UK transactions in the next steps.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# <a id="1.4"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">1.4 Project Structure in General</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#e9a1ed" data-toggle="popover">Table of Contents</a>
#
# **- Data Cleaning & Exploratory Data Analysis**<br>
# **- RFM Analysis**<br>
# **- Customer Segmentation**<br>
# **- Creating Cohorts and Conducting Cohort Analysis**<br>
# **- Conclusion**<br>

# %% [markdown]
# <a id="1.5"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">1.5 What is RFM & Cohort Analysis</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#e9a1ed" data-toggle="popover">Table of Contents</a>
#
# Cohort Analysis and RFM Analysis are **NOT** the same, although they are both analytical techniques used in marketing and customer analysis.
#
# **Cohort analysis** involves **``grouping customers together based on shared characteristics or behaviors``** and then **``analyzing their behavior over time``**. The purpose of Cohort Analysis is to understand how different groups of customers behave or respond to certain events or changes. Cohorts are typically defined by a common attribute or characteristic, such as the month of customer acquisition or a specific marketing campaign. By tracking and comparing the behavior of different cohorts, businesses can gain insights into customer retention, engagement, and other key metrics.
#
# **RFM analysis**, on the other hand, stands for **``Recency``**, **``Frequency``**, **``Monetary``** analysis. It is a technique used to segment customers based on their transactional behavior and a tool of marketing analysis to identify an organization's best customer segment by using certain parameters. These values correspond to crucial customer traits. RFM analysis evaluates three key aspects of customer behavior:
#
# **Recency (R)**: How recently did the customer make a purchase?<br>
# **Frequency (F)**: How often does the customer make purchases?<br>
# **Monetary value (M)**: How much does the customer spend?<br>
#
# RFM analysis assigns numerical scores to each customer based on these dimensions and then groups them into segments or tiers. The resulting segments help businesses identify and target different types of customers, such as high-value customers, loyal customers, or at-risk customers.
#
# In summary, Cohort Analysis focuses on analyzing groups of customers over time, while RFM Analysis focuses on segmenting customers based on their transactional behavior. Both techniques provide valuable insights for understanding customer behavior and optimizing marketing strategies, but they have different approaches and objectives.

# %% [markdown]
# <a id="1.6"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">1.6 Tasks in the Analysis</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#e9a1ed" data-toggle="popover">Table of Contents</a>
#
# - Read the dataset
# - Create a new column named "Age" including random integer numbers between 15 and 85 (Already done for you)
# - Create a new column named "Gender" including the categories of "Female" and "Male" (Already done for you)
# - Create a new column named "Income" (Already done for you)
# - Save and use this new dataset in your RFM Analysis and Cohort Analysis

# %% [markdown]
# <a id="2"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">2) LIBRARIES NEEDED IN THE STUDY<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %%
# import libraries

import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from skimpy import clean_columns
from termcolor import colored
import datetime as dt
import plotly.express as px
import squarify

# %%
# ignore warnings

import warnings
warnings.filterwarnings('ignore')
import math

# %% [markdown]
# <a id="2.1"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">2.1 User Defined Functions<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>
#
# **Define some useful User Defined Functions if needed in your analysis.**

# %%
def first_looking(df, col):
    """
    Prints basic information about a column in a Pandas DataFrame.
    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame to analyze.
    col : str
        The name of the column to analyze.
    Returns:
    --------
    None.
    Prints:
    -------
    column name    : str
        The name of the column being analyzed.
    per_of_nulls   : float
        The percentage of null values in the column.
    num_of_nulls   : int
        The number of null values in the column.
    num_of_uniques : int
        The number of unique values in the column.
    shape_of_df    : tuple
        The shape of the DataFrame.
    The unique values in the column and their frequency of occurrence.
    """
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum() * 100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].astype(str).nunique())
    print("shape_of_df    : ", df.shape)
    print("--------------------------------")
    print(df[col].value_counts(dropna=False))

# %%
def show_distribution(col):
    """
    Plots a histogram and boxplot of a numeric column in a Pandas DataFrame,
    and prints statistical calculations about the column.
    Parameters:
    -----------
    col : Pandas Series
        A numeric column in a Pandas DataFrame.
    Returns:
    --------
    None.
    Prints:
    -------
    Statistical calculations about the column, including minimum value, mean,
    median, mode, and maximum value.
    Plots:
    ------
    A histogram of the column's values, with lines indicating the minimum,
    mean, median, mode, and maximum values.
    A boxplot of the column's values, with a line indicating the median and
    markers indicating the mean and outliers.
    """
    # Get statistics
    from termcolor import colored
    print(colored('Statistical Calculations :', 'red', attrs=['bold']))
    print(colored('-'*26, 'red', attrs=['bold']))
    min_val = col.min()
    max_val = col.max()
    mean_val = col.mean()
    med_val = col.median()
    mod_val = col.mode()[0]
    print(colored('Minimum:{:>7.2f}\nMean:{:>10.2f}\nMedian:{:>8.2f}\nMode:{:>10.2f}\nMaximum:{:>7.2f}\n'.format(min_val,
                                                                                             mean_val,
                                                                                             med_val,
                                                                                             mod_val,
                                                                                             max_val), 'blue', attrs=['bold']))
    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize=(15, 15))
    # Plot the histogram
    ax[0].hist(col, bins=30)
    ax[0].set_ylabel('Frequency', fontsize=10)
    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val,  color='orange',     linestyle='dashed', linewidth=2, label='Minimum')
    ax[0].axvline(x=mean_val, color='lightgreen', linestyle='dashed', linewidth=2, label='Mean')
    ax[0].axvline(x=med_val,  color='cyan',       linestyle='dashed', linewidth=2, label='Median')
    ax[0].axvline(x=mod_val,  color='purple',     linestyle='dashed', linewidth=2, label='Mode')
    ax[0].axvline(x=max_val,  color='red',        linestyle='dashed', linewidth=2, label='Maximum')
    ax[0].legend(loc='upper right')
    # Plot the boxplot
    medianprops = dict(linestyle='-', linewidth=3, color='m')
    boxprops=dict(linestyle='-', linewidth=1.5)
    meanprops={"marker":"d", "markerfacecolor":"blue", "markeredgecolor":"black", "markersize":"10"}
    flierprops={'marker': 'o', 'markersize': 8, 'markerfacecolor': 'fuchsia'}
    ax[1].boxplot(col,
                  vert=False,
                  notch=True,
                  patch_artist=False,
                  medianprops=medianprops,
                  flierprops=flierprops,
                  showmeans=True,
                  meanprops=meanprops)
    ax[1].set_xlabel('value', fontsize=10)
    # Add a title to the Figure
    fig.suptitle('Data Distribution', fontsize=20)

# %% [markdown]
# <a id="3"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">3) ANALYSIS<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# <a id="3.1"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">3.1 Reading the Data<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>
#
# **How to read and assign the dataset as df: You can [Visit Here](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) (You can define it as what you want instead of df)**

# %%
df = pd.read_csv("customer.csv")
df0= df.copy()

# %% [markdown]
# <a id="4"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">4) DATA CLEANING & EXPLORATORY DATA ANALYSIS (EDA)<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# <a id="4.1"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">4.1 - A General Look at the Data<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %%
df.head()
# Out:
#            InvoiceDate InvoiceNo StockCode  \
# 0  2010-12-01 08:26:00    536365    85123A
# 1  2010-12-01 08:26:00    536365     71053
# 2  2010-12-01 08:26:00    536365    84406B
# 3  2010-12-01 08:26:00    536365    84029G
# 4  2010-12-01 08:26:00    536365    84029E
#
#                            Description  Quantity  UnitPrice  CustomerID  Age  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6       2.55     17850.0   77
# 1                  WHITE METAL LANTERN         6       3.39     17850.0   77
# 2       CREAM CUPID HEARTS COAT HANGER         8       2.75     17850.0   77
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39     17850.0   77
# 4       RED WOOLLY HOTTIE WHITE HEART.         6       3.39     17850.0   77
#
#    Gender        Income         Country
# 0  female  26300.794657  United Kingdom
# 1  female  26300.794657  United Kingdom
# 2  female  26300.794657  United Kingdom
# 3  female  26300.794657  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceDate  541909 non-null  object
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Age          541909 non-null  int64
#  8   Gender       541909 non-null  object
#  9   Income       541909 non-null  float64
#  10  Country      541909 non-null  object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 45.5+ MB

# %%
df.shape
# Out:
# (541909, 11)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID            Age  \
# count  541909.000000  541909.000000  406829.000000  541909.000000
# mean        9.552250       4.611114   15287.690570      34.885486
# std       218.081158      96.759853    1713.600303      12.996630
# min    -80995.000000  -11062.060000   12346.000000      15.000000
# 25%         1.000000       1.250000   13953.000000      25.000000
# 50%         3.000000       2.080000   15152.000000      31.000000
# 75%        10.000000       4.130000   16791.000000      43.000000
# max     80995.000000   38970.000000   18287.000000     100.000000
#
#               Income
# count  541909.000000
# mean    33127.125614
# std      5619.977488
# min     18662.725643
# 25%     32130.475292
# 50%     32443.374416
# 75%     33795.299829
# max     45925.206366

# %%
df.isnull().sum()
# Out:
# InvoiceDate         0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# UnitPrice           0
# CustomerID     135080
# Age                 0
# Gender              0
# Income              0
# Country             0
# dtype: int64

# %%
# We have missing data in columns 'Description' and 'CustomerID'.

# %% [markdown]
# <a id="4.2"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">4.2 - The Tasks in This Section<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# **If needed, you can rename columns to be more usable applying Skimpy library:**<br>
# **Get some information by examining descriptive statistics:**<br>
# **Examine the columns/features in the dataset one by one:**<br>
# **Examine if there have some anomilies and missing values in the features. If so, clean the dataset from this noise:**<br>
# **Explore customers by country:**<br>
# **Support your findings with visualization:**<br>
# **During these step, do NOT forget to create some analytical questions and answer to them:**<br>

# %% [markdown]
# ## Clean columns titles

# %%
df=clean_columns(df)
df.head()
# Out:
#           invoice_date invoice_no stock_code  \
# 0  2010-12-01 08:26:00     536365     85123A
# 1  2010-12-01 08:26:00     536365      71053
# 2  2010-12-01 08:26:00     536365     84406B
# 3  2010-12-01 08:26:00     536365     84029G
# 4  2010-12-01 08:26:00     536365     84029E
#
#                            description  quantity  unit_price  customer_id  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55      17850.0
# 1                  WHITE METAL LANTERN         6        3.39      17850.0
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75      17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39      17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39      17850.0
#
#    age  gender        income         country
# 0   77  female  26300.794657  United Kingdom
# 1   77  female  26300.794657  United Kingdom
# 2   77  female  26300.794657  United Kingdom
# 3   77  female  26300.794657  United Kingdom
# ...

# %% [markdown]
# ## Handle Missing Values

# %%
df.isnull().sum()
# Out:
# invoice_date         0
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# unit_price           0
# customer_id     135080
# age                  0
# gender               0
# income               0
# country              0
# dtype: int64

# %%
df[df.customer_id.isnull()]
# Out:
#                invoice_date invoice_no stock_code  \
# 622     2010-12-01 11:52:00     536414      22139
# 1443    2010-12-01 14:32:00     536544      21773
# 1444    2010-12-01 14:32:00     536544      21774
# 1445    2010-12-01 14:32:00     536544      21786
# 1446    2010-12-01 14:32:00     536544      21787
# ...                     ...        ...        ...
# 541536  2011-12-09 10:26:00     581498     85099B
# 541537  2011-12-09 10:26:00     581498     85099C
# 541538  2011-12-09 10:26:00     581498      85150
# 541539  2011-12-09 10:26:00     581498      85174
# 541540  2011-12-09 10:26:00     581498        DOT
#
#                             description  quantity  unit_price  customer_id  \
# 622                                 NaN        56        0.00          NaN
# 1443    DECORATIVE ROSE BATHROOM BOTTLE         1        2.51          NaN
# 1444    DECORATIVE CATS BATHROOM BOTTLE         2        2.51          NaN
# ...

# %%
# Drop rows where customer_id is missing

df = df[df['customer_id'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_date  406829 non-null  object
#  1   invoice_no    406829 non-null  object
#  2   stock_code    406829 non-null  object
#  3   description   406829 non-null  object
#  4   quantity      406829 non-null  int64
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   age           406829 non-null  int64
#  8   gender        406829 non-null  object
#  9   income        406829 non-null  float64
#  10  country       406829 non-null  object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 37.2+ MB

# %% [raw]
# Notice that null values in column 'description' were also missing in column 'customer_id'
# They were dropped as well.

# %%
df.shape
# Out:
# (406829, 11)

# %% [markdown]
# ## Check each column for data anomalies

# %%
df.describe()
# Out:
#             quantity     unit_price    customer_id            age  \
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570      38.167778
# std       248.693370      69.315162    1713.600303      13.482438
# min    -80995.000000       0.000000   12346.000000      15.000000
# 25%         2.000000       1.250000   13953.000000      28.000000
# 50%         5.000000       1.950000   15152.000000      36.000000
# 75%        12.000000       3.750000   16791.000000      45.000000
# max     80995.000000   38970.000000   18287.000000     100.000000
#
#               income
# count  406829.000000
# mean    33458.044810
# std      6452.269506
# min     18662.725643
# 25%     32020.950805
# 50%     32984.648522
# 75%     35183.471003
# max     45925.206366

# %%
df.columns
# Out:
# Index(['invoice_date', 'invoice_no', 'stock_code', 'description', 'quantity',
#        'unit_price', 'customer_id', 'age', 'gender', 'income', 'country'],
#       dtype='object')

# %% [markdown]
# ### Check invoice_date

# %%
first_looking(df,'invoice_date')
# Out:
# column name    :  invoice_date
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  20460
# shape_of_df    :  (406829, 11)
# --------------------------------
# invoice_date
# 2011-11-14 15:27:00    543
# 2011-11-28 15:54:00    534
# 2011-12-05 17:17:00    530
# 2011-11-23 13:39:00    444
# 2011-10-31 14:09:00    436
#                       ...
# 2011-11-15 10:54:00      1
# 2011-04-08 13:20:00      1
# 2011-09-15 17:02:00      1
# 2011-09-15 16:57:00      1
# 2011-03-21 11:02:00      1
# Name: count, Length: 20460, dtype: int64

# %%
# convert datatype to datetime 
df['invoice_date'] = pd.to_datetime(df['invoice_date'])

# %%
df.invoice_date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_date  406829 non-null  datetime64[ns]
#  1   invoice_no    406829 non-null  object
#  2   stock_code    406829 non-null  object
#  3   description   406829 non-null  object
#  4   quantity      406829 non-null  int64
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   age           406829 non-null  int64
#  8   gender        406829 non-null  object
#  9   income        406829 non-null  float64
#  10  country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 37.2+ MB

# %% [markdown]
# ### Check invoice_no

# %%
first_looking(df,'invoice_no')
# Out:
# column name    :  invoice_no
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  22190
# shape_of_df    :  (406829, 11)
# --------------------------------
# invoice_no
# 576339    542
# 579196    533
# 580727    529
# 578270    442
# 573576    435
#          ...
# 554155      1
# 570248      1
# 545414      1
# 545418      1
# 565192      1
# Name: count, Length: 22190, dtype: int64

# %%
df.sample(20)
# Out:
#               invoice_date invoice_no stock_code  \
# 345183 2011-09-16 16:25:00     567153      23275
# 63338  2011-01-19 11:48:00     541565      21258
# 281701 2011-07-28 11:22:00     561595      22725
# 446365 2011-11-07 14:40:00     574893      23583
# 509599 2011-11-29 12:06:00     579387      21592
# 171046 2011-04-28 10:20:00     551351     85130B
# 453890 2011-11-10 09:56:00     575499      23025
# 249988 2011-07-05 11:32:00     558991      22329
# 538019 2011-12-08 12:54:00     581381      21484
# 469976 2011-11-15 16:42:00     576615      23301
# 164543 2011-04-19 16:52:00     550651      22520
# 523892 2011-12-04 15:00:00     580523      22075
# 520319 2011-12-02 13:11:00     580278      22413
# 540187 2011-12-08 19:29:00     581471      21411
# 130417 2011-03-23 11:44:00     547489     85123A
# 218472 2011-06-08 12:54:00     556045      20914
# 445925 2011-11-07 12:29:00     574864      22633
# 214741 2011-06-06 11:55:00     555626      22682
# ...

# %% [raw]
# We see that several invoice_no contain C which denotes 'Cancelled Orders'. Quantity is consistently negative when invoice_no starts with C.

# %%
df[df['invoice_no'].str.contains('C')]
# Out:
#               invoice_date invoice_no stock_code  \
# 141    2010-12-01 09:41:00    C536379          D
# 154    2010-12-01 09:49:00    C536383     35004C
# 235    2010-12-01 10:24:00    C536391      22556
# 236    2010-12-01 10:24:00    C536391      21984
# 237    2010-12-01 10:24:00    C536391      21983
# ...                    ...        ...        ...
# 540449 2011-12-09 09:57:00    C581490      23144
# 541541 2011-12-09 10:28:00    C581499          M
# 541715 2011-12-09 11:57:00    C581568      21258
# 541716 2011-12-09 11:58:00    C581569      84978
# 541717 2011-12-09 11:58:00    C581569      20979
#
#                              description  quantity  unit_price  customer_id  \
# 141                             Discount        -1       27.50      14527.0
# 154      SET OF 3 COLOURED  FLYING DUCKS        -1        4.65      15311.0
# 235       PLASTERS IN TIN CIRCUS PARADE        -12        1.65      17548.0
# ...

# %%
df[df['invoice_no'].str.contains('C')]['quantity'].hist()
# Out:
# <Axes: >

# %%
df[df['invoice_no'].str.contains('C')]['quantity'].describe()
# Out:
# count     8905.000000
# mean       -30.859966
# std       1170.154939
# min     -80995.000000
# 25%         -6.000000
# 50%         -2.000000
# 75%         -1.000000
# max         -1.000000
# Name: quantity, dtype: float64

# %% [raw]
# The histogram and descriptive statistics above verify that quantity is negative if invoice_no contains C character.

# %%
# drop all observations where invoice_no contains C

df=df[~df['invoice_no'].str.contains('C')]

# %%
df.head()
# Out:
#          invoice_date invoice_no stock_code  \
# 0 2010-12-01 08:26:00     536365     85123A
# 1 2010-12-01 08:26:00     536365      71053
# 2 2010-12-01 08:26:00     536365     84406B
# 3 2010-12-01 08:26:00     536365     84029G
# 4 2010-12-01 08:26:00     536365     84029E
#
#                            description  quantity  unit_price  customer_id  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55      17850.0
# 1                  WHITE METAL LANTERN         6        3.39      17850.0
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75      17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39      17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39      17850.0
#
#    age  gender        income         country
# 0   77  female  26300.794657  United Kingdom
# 1   77  female  26300.794657  United Kingdom
# 2   77  female  26300.794657  United Kingdom
# 3   77  female  26300.794657  United Kingdom
# ...

# %% [markdown]
# ### Check quantity

# %%
first_looking(df,'quantity')
# Out:
# column name    :  quantity
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  302
# shape_of_df    :  (397924, 11)
# --------------------------------
# quantity
# 1        73314
# 12       60033
# 2        58003
# 6        37688
# 4        32183
#          ...
# 4300         1
# 608          1
# 738          1
# 552          1
# 80995        1
# Name: count, Length: 302, dtype: int64

# %%
df.quantity.describe()
# Out:
# count    397924.000000
# mean         13.021823
# std         180.420210
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          12.000000
# max       80995.000000
# Name: quantity, dtype: float64

# %%
show_distribution(df['unit_price'])
# Out:
# Statistical Calculations :
# --------------------------
# Minimum:   0.00
# Mean:      3.12
# Median:    1.95
# Mode:      1.25
# Maximum:8142.75

# %% [raw]
# There are no negative values. We do have outliers which we will need to deal with later.

# %% [markdown]
# ### Check unit price

# %%
first_looking(df,'unit_price')
# Out:
# column name    :  unit_price
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  441
# shape_of_df    :  (397924, 11)
# --------------------------------
# unit_price
# 1.25      45841
# 1.65      36834
# 2.95      26562
# 0.85      25968
# 0.42      21812
#           ...
# 6.78          1
# 7.62          1
# 37.50         1
# 1.96          1
# 183.75        1
# Name: count, Length: 441, dtype: int64

# %%
show_distribution(df['unit_price'])
# Out:
# Statistical Calculations :
# --------------------------
# Minimum:   0.00
# Mean:      3.12
# Median:    1.95
# Mode:      1.25
# Maximum:8142.75

# %%
df[df.unit_price==0]
# Out:
#               invoice_date invoice_no stock_code  \
# 9302   2010-12-05 14:02:00     537197      22841
# 33576  2010-12-16 14:36:00     539263      22580
# 40089  2010-12-21 13:45:00     539722      22423
# 47068  2011-01-06 16:41:00     540372      22090
# 47070  2011-01-06 16:41:00     540372      22553
# 56674  2011-01-13 15:10:00     541109      22168
# 86789  2011-02-10 13:08:00     543599     84535B
# 130188 2011-03-23 10:25:00     547417      22062
# 139453 2011-03-30 12:45:00     548318      22055
# 145208 2011-04-04 14:42:00     548871      22162
# 157042 2011-04-14 18:57:00     550188      22636
# 187613 2011-05-12 15:21:00     553000      47566
# 198383 2011-05-20 14:13:00     554037      22619
# 279324 2011-07-26 12:24:00     561284      22167
# 282912 2011-07-28 17:09:00     561669      22960
# 285657 2011-08-01 11:44:00     561916          M
# 298054 2011-08-11 11:42:00     562973      23157
# 314745 2011-08-26 14:19:00     564651      23270
# ...

# %%
df[df.unit_price==0].shape[0]
# Out:
# 40

# %% [raw]
# We find that 40 observations has a price of 0. We drop these observations.

# %%
# drop observations where unit_price <= 0

df = df[df.unit_price>0]
df
# Out:
#               invoice_date invoice_no stock_code  \
# 0      2010-12-01 08:26:00     536365     85123A
# 1      2010-12-01 08:26:00     536365      71053
# 2      2010-12-01 08:26:00     536365     84406B
# 3      2010-12-01 08:26:00     536365     84029G
# 4      2010-12-01 08:26:00     536365     84029E
# ...                    ...        ...        ...
# 541904 2011-12-09 12:50:00     581587      22613
# 541905 2011-12-09 12:50:00     581587      22899
# 541906 2011-12-09 12:50:00     581587      23254
# 541907 2011-12-09 12:50:00     581587      23255
# 541908 2011-12-09 12:50:00     581587      22138
#
#                                 description  quantity  unit_price  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6        2.55
# 1                       WHITE METAL LANTERN         6        3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8        2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39
# ...

# %% [markdown]
# ### check customer_id

# %%
first_looking(df,'customer_id')
# Out:
# column name    :  customer_id
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4338
# shape_of_df    :  (397884, 11)
# --------------------------------
# customer_id
# 17841.0    7847
# 14911.0    5675
# 14096.0    5111
# 12748.0    4595
# 14606.0    2700
#            ...
# 18184.0       1
# 13185.0       1
# 16073.0       1
# 17948.0       1
# 17846.0       1
# Name: count, Length: 4338, dtype: int64

# %% [markdown]
# ### check age

# %%
first_looking(df,'age')
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  80
# shape_of_df    :  (397884, 11)
# --------------------------------
# age
# 28    17104
# 44    16808
# 33    15944
# 29    15530
# 42    14229
#       ...
# 76       41
# 85       32
# 89       31
# 86       22
# 97       14
# Name: count, Length: 80, dtype: int64

# %%
show_distribution(df.age)
# Out:
# Statistical Calculations :
# --------------------------
# Minimum:  15.00
# Mean:     38.16
# Median:   36.00
# Mode:     28.00
# Maximum: 100.00

# %% [raw]
# No anomaly values. Potential outliers.

# %% [markdown]
# ### Check gender

# %%
first_looking(df,'gender')
# Out:
# column name    :  gender
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# shape_of_df    :  (397884, 11)
# --------------------------------
# gender
# female    258034
# male      139850
# Name: count, dtype: int64

# %% [markdown]
# ### Check income

# %%
first_looking(df,'income')
# Out:
# column name    :  income
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4338
# shape_of_df    :  (397884, 11)
# --------------------------------
# income
# 32904.146809    7847
# 32584.481215    5675
# 42889.070502    5111
# 31798.776856    4595
# 31798.349432    2700
#                 ...
# 41045.976050       1
# 19953.584183       1
# 19901.706177       1
# 34227.605558       1
# 33034.511012       1
# Name: count, Length: 4338, dtype: int64

# %%
show_distribution(df.income)
# Out:
# Statistical Calculations :
# --------------------------
# Minimum:18662.73
# Mean:  33459.56
# Median:32985.76
# Mode:  32904.15
# Maximum:45925.21

# %% [markdown]
# ### Check country

# %%
first_looking(df,'country')
# Out:
# column name    :  country
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  37
# shape_of_df    :  (397884, 11)
# --------------------------------
# country
# United Kingdom          354321
# Germany                   9040
# France                    8341
# EIRE                      7236
# Spain                     2484
# Netherlands               2359
# Belgium                   2031
# Switzerland               1841
# Portugal                  1462
# Australia                 1182
# Norway                    1071
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# ...

# %% [markdown]
# ## Check datatype integrity

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'
def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")
check_obj_columns(df)
# Out:
# NO PROBLEM  with the data types of Columns in the DataFrame.

# %% [markdown]
# ## Correct column datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397884 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_date  397884 non-null  datetime64[ns]
#  1   invoice_no    397884 non-null  object
#  2   stock_code    397884 non-null  object
#  3   description   397884 non-null  object
#  4   quantity      397884 non-null  int64
#  5   unit_price    397884 non-null  float64
#  6   customer_id   397884 non-null  float64
#  7   age           397884 non-null  int64
#  8   gender        397884 non-null  object
#  9   income        397884 non-null  float64
#  10  country       397884 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 36.4+ MB

# %%
df.invoice_no = df.invoice_no.astype('string')

# %%
df.stock_code = df.stock_code.astype('string')

# %%
df.customer_id
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: customer_id, Length: 397884, dtype: float64

# %%
df.customer_id = df.customer_id.astype(int)

# %%
df.customer_id
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 541904    12680
# 541905    12680
# 541906    12680
# 541907    12680
# 541908    12680
# Name: customer_id, Length: 397884, dtype: int32

# %%
df.customer_id = df.customer_id.astype('string')

# %%
df.customer_id
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 541904    12680
# 541905    12680
# 541906    12680
# 541907    12680
# 541908    12680
# Name: customer_id, Length: 397884, dtype: string

# %%
df.gender = df.gender.astype('string')

# %%
df.country = df.country.astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397884 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_date  397884 non-null  datetime64[ns]
#  1   invoice_no    397884 non-null  string
#  2   stock_code    397884 non-null  string
#  3   description   397884 non-null  object
#  4   quantity      397884 non-null  int64
#  5   unit_price    397884 non-null  float64
#  6   customer_id   397884 non-null  string
#  7   age           397884 non-null  int64
#  8   gender        397884 non-null  string
#  9   income        397884 non-null  float64
#  10  country       397884 non-null  string
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1), string(5)
# memory usage: 36.4+ MB

# %% [raw]
# We have only description column as object. We will not be using this column in our analyses.

# %%
df_cleaned = df

# %% [markdown]
# #### We will continue to work with df in the EDA process. Here we filter UK data to work with in the next stages of our analysis (RFM, Segmentation, Cohort Analyis)

# %%
df_uk = df[df['country']=='United Kingdom']

# %%
df_uk
# Out:
#               invoice_date invoice_no stock_code  \
# 0      2010-12-01 08:26:00     536365     85123A
# 1      2010-12-01 08:26:00     536365      71053
# 2      2010-12-01 08:26:00     536365     84406B
# 3      2010-12-01 08:26:00     536365     84029G
# 4      2010-12-01 08:26:00     536365     84029E
# ...                    ...        ...        ...
# 541889 2011-12-09 12:31:00     581585      22466
# 541890 2011-12-09 12:49:00     581586      22061
# 541891 2011-12-09 12:49:00     581586      23275
# 541892 2011-12-09 12:49:00     581586      21217
# 541893 2011-12-09 12:49:00     581586      20685
#
#                                 description  quantity  unit_price customer_id  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6        2.55       17850
# 1                       WHITE METAL LANTERN         6        3.39       17850
# 2            CREAM CUPID HEARTS COAT HANGER         8        2.75       17850
# ...

# %%
df_uk.country.value_counts()
# Out:
# country
# United Kingdom    354321
# Name: count, dtype: Int64

# %% [markdown]
# ### Create revenue

# %%
df['revenue'] = df['quantity'] * df['unit_price']

# %% [markdown]
# # Create order level aggregates

# %% [markdown]
# ### Create number of unique items per order

# %%
df['order_unique_items'] = df.groupby('invoice_no')['stock_code'].transform('count')

# %%
df[df['invoice_no']=='536365']
# Out:
#          invoice_date invoice_no stock_code  \
# 0 2010-12-01 08:26:00     536365     85123A
# 1 2010-12-01 08:26:00     536365      71053
# 2 2010-12-01 08:26:00     536365     84406B
# 3 2010-12-01 08:26:00     536365     84029G
# 4 2010-12-01 08:26:00     536365     84029E
# 5 2010-12-01 08:26:00     536365      22752
# 6 2010-12-01 08:26:00     536365      21730
#
#                            description  quantity  unit_price customer_id  age  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55       17850   77
# 1                  WHITE METAL LANTERN         6        3.39       17850   77
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75       17850   77
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39       17850   77
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39       17850   77
# 5         SET 7 BABUSHKA NESTING BOXES         2        7.65       17850   77
# ...

# %% [markdown]
# ### Create total_quantity per order

# %%
df['order_total_quantity'] = df.groupby('invoice_no')['quantity'].transform('sum')

# %%
df[df['invoice_no']=='536365']
# Out:
#          invoice_date invoice_no stock_code  \
# 0 2010-12-01 08:26:00     536365     85123A
# 1 2010-12-01 08:26:00     536365      71053
# 2 2010-12-01 08:26:00     536365     84406B
# 3 2010-12-01 08:26:00     536365     84029G
# 4 2010-12-01 08:26:00     536365     84029E
# 5 2010-12-01 08:26:00     536365      22752
# 6 2010-12-01 08:26:00     536365      21730
#
#                            description  quantity  unit_price customer_id  age  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55       17850   77
# 1                  WHITE METAL LANTERN         6        3.39       17850   77
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75       17850   77
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39       17850   77
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39       17850   77
# 5         SET 7 BABUSHKA NESTING BOXES         2        7.65       17850   77
# ...

# %% [markdown]
# ### Create total_price per order

# %%
df['order_total_price'] = df.groupby('invoice_no')['revenue'].transform('sum')

# %%
df[df['invoice_no']=='536365']
# Out:
#          invoice_date invoice_no stock_code  \
# 0 2010-12-01 08:26:00     536365     85123A
# 1 2010-12-01 08:26:00     536365      71053
# 2 2010-12-01 08:26:00     536365     84406B
# 3 2010-12-01 08:26:00     536365     84029G
# 4 2010-12-01 08:26:00     536365     84029E
# 5 2010-12-01 08:26:00     536365      22752
# 6 2010-12-01 08:26:00     536365      21730
#
#                            description  quantity  unit_price customer_id  age  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55       17850   77
# 1                  WHITE METAL LANTERN         6        3.39       17850   77
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75       17850   77
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39       17850   77
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39       17850   77
# 5         SET 7 BABUSHKA NESTING BOXES         2        7.65       17850   77
# ...

# %% [markdown]
# # Create a new dataframe where each row represents unique orders

# %%
df.drop(['stock_code', 'description', 'quantity', 'unit_price', 'revenue'], axis=1, inplace=True)

# %%
df
# Out:
#               invoice_date invoice_no customer_id  age  gender        income  \
# 0      2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1      2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 2      2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 3      2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 4      2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# ...                    ...        ...         ...  ...     ...           ...
# 541904 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
# 541905 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
# 541906 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
# 541907 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
# 541908 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %%
df1 = df.drop_duplicates().reset_index(drop=True)

# %%
df1
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 0     2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1     2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2     2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3     2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4     2010-12-01 08:35:00     536369       13047   64  female  40881.687219
# ...                   ...        ...         ...  ...     ...           ...
# 18557 2011-12-09 12:23:00     581583       13777   40  female  32712.707784
# 18558 2011-12-09 12:25:00     581584       13777   40  female  32712.707784
# 18559 2011-12-09 12:31:00     581585       15804   30  female  33151.297921
# 18560 2011-12-09 12:49:00     581586       13113   34  female  33687.081490
# 18561 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %%
df1.duplicated().value_counts()
# Out:
# False    18562
# Name: count, dtype: int64

# %% [markdown]
# # Customer level aggregates

# %%
# number of orders per customer

df1['customer_order_count'] = df1.groupby('customer_id')['invoice_no'].transform('count')

# %% [raw]
# df1[df1['customer_id']=='12680']

# %%
# total revenue per customer
df1['customer_revenue'] = df1.groupby('customer_id')['order_total_price'].transform('sum')

# %%
df1[df1['customer_id']=='12680']
# Out:
#              invoice_date invoice_no customer_id  age gender        income  \
# 10911 2011-08-18 15:44:00     563712       12680   26   male  31414.340477
# 11962 2011-09-11 12:27:00     566256       12680   26   male  31414.340477
# 12913 2011-09-27 12:53:00     568518       12680   26   male  31414.340477
# 18561 2011-12-09 12:50:00     581587       12680   26   male  31414.340477
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 10911  France                  20                   230             311.78
# 11962  France                   7                    43             112.38
# 12913  France                  10                    65             189.20
# 18561  France                  15                   105             249.45
#
#        customer_order_count  customer_revenue
# 10911                     4            862.81
# 11962                     4            862.81
# 12913                     4            862.81
# ...

# %% [markdown]
# # Country level aggregates

# %%
# number of orders per country

df1['country_order_count'] = df1.groupby('country')['invoice_no'].transform('count')

# %%
df1.head()
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1 2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2 2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3 2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4 2010-12-01 08:35:00     536369       13047   64  female  40881.687219
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
# 1  United Kingdom                   2                    12
# 2  United Kingdom                  12                    83
# 3  United Kingdom                   4                    15
# 4  United Kingdom                   1                     3
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
# ...

# %%
# number of customers per country

df1['country_customer_count'] = df1.groupby('country')['customer_id'].transform(pd.Series.nunique)

# %%
df1.head()
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1 2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2 2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3 2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4 2010-12-01 08:35:00     536369       13047   64  female  40881.687219
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
# 1  United Kingdom                   2                    12
# 2  United Kingdom                  12                    83
# 3  United Kingdom                   4                    15
# 4  United Kingdom                   1                     3
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
# ...

# %%
df1.country.value_counts()
# Out:
# country
# United Kingdom          16673
# Germany                   457
# France                    390
# EIRE                      261
# Belgium                    98
# Netherlands                94
# Spain                      90
# Australia                  57
# Portugal                   57
# Switzerland                51
# Finland                    41
# Italy                      38
# Norway                     36
# Sweden                     36
# Channel Islands            26
# Japan                      20
# Poland                     19
# Denmark                    18
# Austria                    17
# Cyprus                     16
# Unspecified                 8
# Iceland                     7
# Singapore                   7
# Canada                      6
# USA                         5
# Greece                      5
# Malta                       5
# Israel                      5
# European Community          4
# Lithuania                   4
# ...

# %%
df1[df1['country']=='Canada']
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 3918  2011-03-14 13:53:00     546533       15388   19    male  20321.269116
# 5959  2011-05-04 10:47:00     551736       17443   32  female  31667.983498
# 8336  2011-06-20 09:04:00     557322       17444   40  female  32300.495609
# 9207  2011-07-11 10:33:00     559557       17444   40  female  32300.495609
# 9438  2011-07-15 12:05:00     560187       17444   40  female  32300.495609
# 11240 2011-08-25 11:27:00     564428       17844   29  female  32828.875097
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 3918   Canada                  10                    88             140.54
# 5959   Canada                   1                   504             534.24
# 8336   Canada                  57                  1092            1171.46
# 9207   Canada                  77                  1026            1217.64
# ...

# %%
# total revenue per country

df1['country_total_revenue'] = df1.groupby('country')['order_total_price'].transform('sum')

# %%
df1[df1['country']=='Canada']
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 3918  2011-03-14 13:53:00     546533       15388   19    male  20321.269116
# 5959  2011-05-04 10:47:00     551736       17443   32  female  31667.983498
# 8336  2011-06-20 09:04:00     557322       17444   40  female  32300.495609
# 9207  2011-07-11 10:33:00     559557       17444   40  female  32300.495609
# 9438  2011-07-15 12:05:00     560187       17444   40  female  32300.495609
# 11240 2011-08-25 11:27:00     564428       17844   29  female  32828.875097
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 3918   Canada                  10                    88             140.54
# 5959   Canada                   1                   504             534.24
# 8336   Canada                  57                  1092            1171.46
# 9207   Canada                  77                  1026            1217.64
# ...

# %% [raw]
# Now that we have changed the shape of our data from product-based row level data to order-based row level data, we can deal with the outliers.
# After we deal with the outliers, we will calculate our customer and country level aggregates.

# %%
df1
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 0     2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1     2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2     2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3     2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4     2010-12-01 08:35:00     536369       13047   64  female  40881.687219
# ...                   ...        ...         ...  ...     ...           ...
# 18557 2011-12-09 12:23:00     581583       13777   40  female  32712.707784
# 18558 2011-12-09 12:25:00     581584       13777   40  female  32712.707784
# 18559 2011-12-09 12:31:00     581585       15804   30  female  33151.297921
# 18560 2011-12-09 12:49:00     581586       13113   34  female  33687.081490
# 18561 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %% [markdown]
# # Descriptive Analyses with Outliers included

# %% [markdown]
# ## Customer-level Analyses

# %% [markdown]
# ### 1-Number of Orders per Customer

# %%
customer_order_count =df1[['customer_id', 'customer_order_count']].drop_duplicates()

customer_order_count.sort_values(by='customer_order_count', ascending=False, inplace=False).head(15)
# Out:
#      customer_id  customer_order_count
# 61         12748                   210
# 80         14911                   202
# 85         17841                   124
# 318        13089                    97
# 116        14606                    95
# 15         15311                    91
# 232        12971                    86
# 1297       14646                    73
# 19         16029                    63
# 26         13408                    62
# 563        18102                    60
# 241        13798                    57
# 273        14156                    55
# 366        14527                    55
# 392        16422                    51

# %%
sns.histplot(data=customer_order_count, x='customer_order_count', bins=50);

# %% [markdown]
# ## 2- Total Order Value per Customer

# %%
df1.head(1)
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
#
#    country_order_count  country_customer_count  country_total_revenue
# 0                16673                    3920            7324982.664

# %%
customer_order_total = df1[['customer_id', 'customer_revenue']].drop_duplicates()

customer_order_total.sort_values(by='customer_revenue', ascending=False, inplace=False).head(15)
# Out:
#       customer_id  customer_revenue
# 1297        14646         280206.02
# 563         18102         259657.30
# 499         17450         194550.79
# 6766        16446         168472.50
# 80          14911         145009.28
# 1493        12415         124914.53
# 273         14156         117379.63
# 23          17511          94399.14
# 19          16029          81024.84
# 1911        12346          77183.60
# 1199        16684          66653.56
# 11378       14096          65164.79
# 48          13694          65039.62
# 15          15311          60767.90
# 318         13089          58825.83

# %%
sns.histplot(data=customer_order_total, x='customer_revenue', bins=50);

# %% [markdown]
# ### total revenue per country

# %%
df1.head(1)
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
#
#    country_order_count  country_customer_count  country_total_revenue
# 0                16673                    3920            7324982.664

# %%
country_revenue = df1[['country', 'country_total_revenue']].drop_duplicates().sort_values(by='country_total_revenue', ascending=False)
country_revenue
# Out:
#                     country  country_total_revenue
# 0            United Kingdom            7324982.664
# 35              Netherlands             285446.340
# 80                     EIRE             266730.120
# 67                  Germany             228867.140
# 5                    France             210540.730
# 22                Australia             138521.310
# 276                   Spain              61577.110
# 266             Switzerland              56443.950
# 310                 Belgium              41196.340
# 1006                 Sweden              38378.330
# 396                   Japan              37461.940
# 72                   Norway              36165.440
# 304                Portugal              33439.890
# 1214                Finland              22546.080
# 2148              Singapore              21279.290
# 708         Channel Islands              20450.440
# 709                 Denmark              18955.340
# ...

# %%
largest = country_revenue['country_total_revenue'].nlargest(2).reset_index(drop=True)
plt.figure(figsize=(12, 8))
ax = sns.barplot(x="country_total_revenue", y="country", data=country_revenue)

# Add figures as annotations above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_width():.0f}', (p.get_width() + 1, p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=8, color='black')
    if p.get_width() > largest[1]:  # Eğer çubuk genişliği 500'den büyükse annotasyonu sağa kaydır
        ax.annotate(f'{p.get_width():.0f}', (p.get_width() - (largest[0] -  math.ceil(largest[1]+largest[1]*0.1)) , p.get_y() + p.get_height() / 2),
                    ha='right', va='center', fontsize=8, color='black')

plt.xlabel('Revenue')
plt.ylabel('Country')
plt.title('Distribution of Revenue by Country')
plt.tight_layout()
plt.xlim(0, math.ceil(largest[1]+largest[1]*0.1))
plt.show()

# %% [markdown]
# ### number of customers per country

# %%
df1.head(1)
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
#
#    country_order_count  country_customer_count  country_total_revenue
# 0                16673                    3920            7324982.664

# %%
country_customer_count =df1[['country', 'country_customer_count']].drop_duplicates().sort_values(by='country_customer_count', ascending=False)
country_customer_count
# Out:
#                     country  country_customer_count
# 0            United Kingdom                    3920
# 67                  Germany                      94
# 5                    France                      87
# 276                   Spain                      30
# 310                 Belgium                      25
# 266             Switzerland                      21
# 304                Portugal                      19
# 308                   Italy                      14
# 1214                Finland                      12
# 1224                Austria                      11
# 72                   Norway                      10
# 708         Channel Islands                       9
# 22                Australia                       9
# 35              Netherlands                       9
# 709                 Denmark                       9
# 1006                 Sweden                       8
# 992                  Cyprus                       8
# ...

# %%
plt.figure(figsize=(12, 8))
ax = sns.barplot(x="country_customer_count", y="country", data=country_customer_count)

# Add figures as annotations above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_width():.0f}', (p.get_width() + 1, p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=8, color='black')
    if p.get_width() > 100:  # Eğer çubuk genişliği 500'den büyükse annotasyonu sağa kaydır
        ax.annotate(f'{p.get_width():.0f}', (p.get_width() - 3821, p.get_y() + p.get_height() / 2),
                    ha='right', va='center', fontsize=8, color='black')

plt.xlabel('Customers')
plt.ylabel('Country')
plt.title('Distribution of Customers by Country')
plt.tight_layout()
plt.xlim(0, 100)
plt.show();

# %% [markdown]
# ### number of orders per country

# %%
df1.head(1)
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
#
#    country_order_count  country_customer_count  country_total_revenue
# 0                16673                    3920            7324982.664

# %%
country_order_count = df1[['country', 'country_order_count']].drop_duplicates().sort_values(by='country_order_count', ascending=False)
country_order_count
# Out:
#                     country  country_order_count
# 0            United Kingdom                16673
# 67                  Germany                  457
# 5                    France                  390
# 80                     EIRE                  261
# 310                 Belgium                   98
# 35              Netherlands                   94
# 276                   Spain                   90
# 22                Australia                   57
# 304                Portugal                   57
# 266             Switzerland                   51
# 1214                Finland                   41
# 308                   Italy                   38
# 72                   Norway                   36
# 1006                 Sweden                   36
# 708         Channel Islands                   26
# 396                   Japan                   20
# 288                  Poland                   19
# 709                 Denmark                   18
# ...

# %%
plt.figure(figsize=(12, 8))
ax = sns.barplot(x="country_order_count", y="country", data=country_order_count)

# Add figures as annotations above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_width():.0f}', (p.get_width() + 1, p.get_y() + p.get_height() / 2),
                ha='left', va='center', fontsize=8, color='black')
    if p.get_width() > 500:  # Eğer çubuk genişliği 500'den büyükse annotasyonu sağa kaydır
        ax.annotate(f'{p.get_width():.0f}', (p.get_width() - 16175, p.get_y() + p.get_height() / 2),
                    ha='right', va='center', fontsize=8, color='black')

plt.xlabel('Orders')
plt.ylabel('Country')
plt.title('Distribution of Orders by Country')
plt.tight_layout()
plt.xlim(0, 500)
plt.show()

# %% [markdown]
# ### Revenue by Week

# %%
fig = px.bar(df1[['invoice_date', 'order_total_price']].set_index('invoice_date').resample('W').sum().reset_index(),
x='invoice_date', y='order_total_price', title= 'Revenue by week', color='order_total_price')
fig.show()

# %%
df1.head(1)
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
#
#    country_order_count  country_customer_count  country_total_revenue
# 0                16673                    3920            7324982.664

# %%
fig = px.bar(df1[['invoice_date', 'order_total_price']].set_index('invoice_date').resample('M').sum().reset_index(),
x='invoice_date', y='order_total_price', title= 'Revenue by Month', color='order_total_price')
fig.show()

# %%
fig = px.bar(df1[['invoice_date', 'invoice_no']].set_index('invoice_date').resample('M').count().reset_index(),
x='invoice_date', y='invoice_no', title= 'Number of Orders by Month', color='invoice_no')
fig.show()

# %% [markdown]
# # Outliers

# %%
df2 = df1.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18562 entries, 0 to 18561
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   invoice_date            18562 non-null  datetime64[ns]
#  1   invoice_no              18562 non-null  string
#  2   customer_id             18562 non-null  string
#  3   age                     18562 non-null  int64
#  4   gender                  18562 non-null  string
#  5   income                  18562 non-null  float64
#  6   country                 18562 non-null  string
#  7   order_unique_items      18562 non-null  int64
#  8   order_total_quantity    18562 non-null  int64
#  9   order_total_price       18562 non-null  float64
#  10  customer_order_count    18562 non-null  int64
#  11  customer_revenue        18562 non-null  float64
#  12  country_order_count     18562 non-null  int64
#  13  country_customer_count  18562 non-null  int64
# ...

# %% [raw]
# There are a number of different ways to identify and handle outliers.
# We, here, use 'z-score greater than 3' condition to identify outliers.

# %% [markdown]
# ## Checking age against outliers

# %%
sns.boxplot(x=df2.age);

# %%
sns.histplot(data=df2, x='age', bins=50);

# %%
print("Number of rows before dropping outliers:", len(df2))
# Out:
# Number of rows before dropping outliers: 18562

# %%
z_scores = np.abs((df2["age"] - df2["age"].mean()) / df2["age"].std())
z_scores
# Out:
# 0        2.816931
# 1        2.816931
# 2        1.877504
# 3        1.877504
# 4        1.877504
#            ...
# 18557    0.143176
# 18558    0.143176
# 18559    0.579460
# 18560    0.290405
# 18561    0.868515
# Name: age, Length: 18562, dtype: float64

# %%
df2[z_scores > 3]
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 246   2010-12-02 17:51:00     536834       14576   88  female  25638.211310
# 410   2010-12-06 09:52:00     537236       16858   93  female  26342.593483
# 745   2010-12-09 14:44:00     538086       12872   93  female  26905.655508
# 1049  2010-12-15 10:57:00     538917       17449   88    male  25462.892190
# 1165  2010-12-16 13:43:00     539249       14709   96  female  26253.507701
# ...                   ...        ...         ...  ...     ...           ...
# 17727 2011-11-30 12:18:00     579634       12598   95  female  26149.575803
# 17958 2011-12-02 13:15:00     580281       12704   98  female  25785.123156
# 18040 2011-12-04 12:17:00     580438       12827   81  female  26165.258528
# 18044 2011-12-04 12:32:00     580469       14583   90  female  26632.766899
# 18402 2011-12-07 16:56:00     581191       17449   88    male  25462.892190
#
# ...

# %%
df2 = df2[z_scores < 3]
df2.reset_index(drop=True, inplace=True)
print("Number of rows after dropping outliers:", len(df2))
# Out:
# Number of rows after dropping outliers: 18452

# %% [markdown]
# ## Checking income against outliers

# %%
sns.boxplot(x=df2.income);

# %%
sns.histplot(data=df2, x='income', bins=50);

# %%
print("Number of rows before dropping outliers:", len(df2))
# Out:
# Number of rows before dropping outliers: 18452

# %%
z_scores = np.abs((df2["income"] - df2["income"].mean()) / df2["income"].std())
z_scores
# Out:
# 0        1.058243
# 1        1.058243
# 2        1.162330
# 3        1.162330
# 4        1.162330
#            ...
# 18447    0.081751
# 18448    0.081751
# 18449    0.014957
# 18450    0.066639
# 18451    0.279484
# Name: income, Length: 18452, dtype: float64

# %%
df2[z_scores > 3]
# Out:
# Empty DataFrame
# Columns: [invoice_date, invoice_no, customer_id, age, gender, income, country, order_unique_items, order_total_quantity, order_total_price, customer_order_count, customer_revenue, country_order_count, country_customer_count, country_total_revenue]
# Index: []

# %%
# No outliers in income according to 3 standard deviations rule

# %% [markdown]
# ## Checking order_total_price against outliers

# %%
sns.boxplot(x=np.log(df2.order_total_price));

# %%
sns.histplot(data=df2, x=np.log(df2.order_total_price), bins=50);

# %%
print("Number of rows before dropping outliers:", len(df2))
# Out:
# Number of rows before dropping outliers: 18452

# %%
z_scores = np.abs((np.log(df2.order_total_price) - np.log(df2.order_total_price).mean()) / np.log(df2.order_total_price).std())
z_scores
# Out:
# 0        0.604482
# 1        2.314273
# 2        0.042922
# 3        1.243707
# 4        2.517454
#            ...
# 18447    0.707175
# 18448    0.594358
# 18449    0.197543
# 18450    0.225847
# 18451    0.060476
# Name: order_total_price, Length: 18452, dtype: float64

# %%
df2[z_scores > 3]
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 61    2010-12-01 12:48:00     536521       12748   29    male  31798.776856
# 94    2010-12-01 15:28:00     536568       16048   20  female  20064.455533
# 161   2010-12-02 11:46:00     536641       12748   29    male  31798.776856
# 324   2010-12-05 11:03:00     537048       13069   28    male  32081.210646
# 390   2010-12-05 15:26:00     537213       12748   29    male  31798.776856
# ...                   ...        ...         ...  ...     ...           ...
# 18159 2011-12-06 13:45:00     580916       13685   58  female  40234.367226
# 18231 2011-12-07 12:14:00     581105       16000   44  female  32745.452773
# 18280 2011-12-07 15:16:00     581175       14646   49  female  44358.814114
# 18401 2011-12-08 18:43:00     581457       18102   42    male  34726.599227
# 18419 2011-12-09 09:15:00     581483       16446   51  female  41446.747462
#
# ...

# %%
df2 = df2[z_scores < 3]
df2.reset_index(drop=True, inplace=True)
print("Number of rows after dropping outliers:", len(df2))
# Out:
# Number of rows after dropping outliers: 18128

# %% [markdown]
# ## Checking order_total_quantity against outliers

# %%
sns.boxplot(x=np.log(df2.order_total_quantity));

# %%
sns.histplot(data=df2, x=np.log(df2.order_total_quantity), bins=50);

# %%
print("Number of rows before dropping outliers:", len(df2))
# Out:
# Number of rows before dropping outliers: 18128

# %%
z_scores = np.abs((np.log(df2.order_total_quantity) - np.log(df2.order_total_quantity).mean()) / np.log(df2.order_total_quantity).std())
z_scores
# Out:
# 0        1.044238
# 1        2.053351
# 2        0.432419
# 3        1.866323
# 4        3.215278
#            ...
# 18123    0.506267
# 18124    0.123433
# 18125    0.580723
# 18126    0.624512
# 18127    0.235353
# Name: order_total_quantity, Length: 18128, dtype: float64

# %%
df2[z_scores > 3]
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 4     2010-12-01 08:35:00     536369       13047   64  female  40881.687219
# 98    2010-12-01 15:46:00     536574       17025   35    male  34553.720981
# 109   2010-12-01 16:24:00     536585       17460   29    male  32904.742169
# 204   2010-12-02 15:08:00     536779       15823   20  female  20076.588446
# 243   2010-12-02 18:06:00     536835       13145   59  female  40223.641569
# ...                   ...        ...         ...  ...     ...           ...
# 17346 2011-11-30 15:38:00     579790       12784   33  female  34010.611170
# 17383 2011-12-01 10:45:00     579947       15993   55  female  40297.709156
# 17557 2011-12-02 14:16:00     580302       16103   15    male  20390.651290
# 17579 2011-12-02 16:06:00     580356       18109   26  female  31809.238980
# 17926 2011-12-07 12:45:00     581127       16271   53    male  43662.290492
#
# ...

# %%
df2 = df2[z_scores < 3]
df2.reset_index(drop=True, inplace=True)
print("Number of rows after dropping outliers:", len(df2))
# Out:
# Number of rows after dropping outliers: 17902

# %% [markdown]
# # Customer level aggregates

# %%
# number of orders per customer

df2['customer_order_count'] = df2.groupby('customer_id')['invoice_no'].transform('count')

# %%
df2[df2['customer_id']=='12680']
# Out:
#              invoice_date invoice_no customer_id  age gender        income  \
# 10503 2011-08-18 15:44:00     563712       12680   26   male  31414.340477
# 11520 2011-09-11 12:27:00     566256       12680   26   male  31414.340477
# 12443 2011-09-27 12:53:00     568518       12680   26   male  31414.340477
# 17901 2011-12-09 12:50:00     581587       12680   26   male  31414.340477
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 10503  France                  20                   230             311.78
# 11520  France                   7                    43             112.38
# 12443  France                  10                    65             189.20
# 17901  France                  15                   105             249.45
#
#        customer_order_count  customer_revenue  country_order_count  \
# 10503                     4            862.81                  390
# 11520                     4            862.81                  390
# ...

# %%
# total revenue per customer
df2['customer_revenue'] = df2.groupby('customer_id')['order_total_price'].transform('sum')

# %%
df2[df2['customer_id']=='12680']
# Out:
#              invoice_date invoice_no customer_id  age gender        income  \
# 10503 2011-08-18 15:44:00     563712       12680   26   male  31414.340477
# 11520 2011-09-11 12:27:00     566256       12680   26   male  31414.340477
# 12443 2011-09-27 12:53:00     568518       12680   26   male  31414.340477
# 17901 2011-12-09 12:50:00     581587       12680   26   male  31414.340477
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 10503  France                  20                   230             311.78
# 11520  France                   7                    43             112.38
# 12443  France                  10                    65             189.20
# 17901  France                  15                   105             249.45
#
#        customer_order_count  customer_revenue  country_order_count  \
# 10503                     4            862.81                  390
# 11520                     4            862.81                  390
# ...

# %% [markdown]
# # Country level aggregates

# %%
# number of orders per country

df2['country_order_count'] = df2.groupby('country')['invoice_no'].transform('count')

# %%
df2.head()
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1 2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2 2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3 2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4 2010-12-01 08:45:00     536370       12583   59  female  40350.231046
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
# 1  United Kingdom                   2                    12
# 2  United Kingdom                  12                    83
# 3  United Kingdom                   4                    15
# 4          France                  20                   449
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
# ...

# %%
# number of customers per country

df2['country_customer_count'] = df2.groupby('country')['customer_id'].transform(pd.Series.nunique)

# %%
df2.head()
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1 2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2 2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3 2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4 2010-12-01 08:45:00     536370       12583   59  female  40350.231046
#
#           country  order_unique_items  order_total_quantity  \
# 0  United Kingdom                   7                    40
# 1  United Kingdom                   2                    12
# 2  United Kingdom                  12                    83
# 3  United Kingdom                   4                    15
# 4          France                  20                   449
#
#    order_total_price  customer_order_count  customer_revenue  \
# 0             139.12                    34           5391.21
# ...

# %%
df2.country.value_counts()
# Out:
# country
# United Kingdom          16138
# Germany                   442
# France                    364
# EIRE                      247
# Belgium                    98
# Spain                      88
# Netherlands                75
# Switzerland                49
# Portugal                   49
# Australia                  49
# Italy                      35
# Norway                     32
# Finland                    32
# Sweden                     31
# Channel Islands            25
# Poland                     19
# Japan                      18
# Denmark                    18
# Austria                    17
# Cyprus                     14
# Unspecified                 8
# Iceland                     7
# USA                         5
# Greece                      5
# Singapore                   5
# Malta                       5
# Israel                      5
# Canada                      5
# Lithuania                   4
# European Community          3
# ...

# %%
df2[df2['country']=='Canada']
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 3760  2011-03-14 13:53:00     546533       15388   19    male  20321.269116
# 5739  2011-05-04 10:47:00     551736       17443   32  female  31667.983498
# 8028  2011-06-20 09:04:00     557322       17444   40  female  32300.495609
# 8862  2011-07-11 10:33:00     559557       17444   40  female  32300.495609
# 10825 2011-08-25 11:27:00     564428       17844   29  female  32828.875097
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 3760   Canada                  10                    88             140.54
# 5739   Canada                   1                   504             534.24
# 8028   Canada                  57                  1092            1171.46
# 8862   Canada                  77                  1026            1217.64
# 10825  Canada                   5                    52              51.56
#
# ...

# %%
# total revenue per country

df2['country_total_revenue'] = df2.groupby('country')['order_total_price'].transform('sum')

# %%
df2[df2['country']=='Canada']
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 3760  2011-03-14 13:53:00     546533       15388   19    male  20321.269116
# 5739  2011-05-04 10:47:00     551736       17443   32  female  31667.983498
# 8028  2011-06-20 09:04:00     557322       17444   40  female  32300.495609
# 8862  2011-07-11 10:33:00     559557       17444   40  female  32300.495609
# 10825 2011-08-25 11:27:00     564428       17844   29  female  32828.875097
#
#       country  order_unique_items  order_total_quantity  order_total_price  \
# 3760   Canada                  10                    88             140.54
# 5739   Canada                   1                   504             534.24
# 8028   Canada                  57                  1092            1171.46
# 8862   Canada                  77                  1026            1217.64
# 10825  Canada                   5                    52              51.56
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17902 entries, 0 to 17901
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   invoice_date            17902 non-null  datetime64[ns]
#  1   invoice_no              17902 non-null  string
#  2   customer_id             17902 non-null  string
#  3   age                     17902 non-null  int64
#  4   gender                  17902 non-null  string
#  5   income                  17902 non-null  float64
#  6   country                 17902 non-null  string
#  7   order_unique_items      17902 non-null  int64
#  8   order_total_quantity    17902 non-null  int64
#  9   order_total_price       17902 non-null  float64
#  10  customer_order_count    17902 non-null  int64
#  11  customer_revenue        17902 non-null  float64
#  12  country_order_count     17902 non-null  int64
#  13  country_customer_count  17902 non-null  int64
# ...

# %%
df2
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 0     2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1     2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2     2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3     2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4     2010-12-01 08:45:00     536370       12583   59  female  40350.231046
# ...                   ...        ...         ...  ...     ...           ...
# 17897 2011-12-09 12:23:00     581583       13777   40  female  32712.707784
# 17898 2011-12-09 12:25:00     581584       13777   40  female  32712.707784
# 17899 2011-12-09 12:31:00     581585       15804   30  female  33151.297921
# 17900 2011-12-09 12:49:00     581586       13113   34  female  33687.081490
# 17901 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %% [markdown]
# # Inferential Analyses

# %% [markdown]
# ## Is there a gender effect on number of orders and amount spent?
# a) Do females place more orders than males?
#
# b) Do females spend more than males?
#
# Statistical Method : independent samples t-test

# %% [markdown]
# ### a)Is there a difference between males and females in number of orders placed?

# %% [raw]
# # State the null and alternative hypotheses
# H0: mu1 = mu2
#
# H1: mu1 != mu2

# %%
df2
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 0     2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1     2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2     2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3     2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4     2010-12-01 08:45:00     536370       12583   59  female  40350.231046
# ...                   ...        ...         ...  ...     ...           ...
# 17897 2011-12-09 12:23:00     581583       13777   40  female  32712.707784
# 17898 2011-12-09 12:25:00     581584       13777   40  female  32712.707784
# 17899 2011-12-09 12:31:00     581585       15804   30  female  33151.297921
# 17900 2011-12-09 12:49:00     581586       13113   34  female  33687.081490
# 17901 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %%
gender_hypo1 = df2[['customer_id','gender', 'customer_order_count']].drop_duplicates()

# %%
gender_hypo1.gender.value_counts()
# Out:
# gender
# female    2875
# male      1409
# Name: count, dtype: Int64

# %%
female1 = gender_hypo1[gender_hypo1["gender"]=='female']
female1
# Out:
#       customer_id  gender  customer_order_count
# 0           17850  female                    34
# 2           13047  female                     8
# 4           12583  female                    15
# 5           13748  female                     5
# 8           15100  female                     3
# ...           ...     ...                   ...
# 17692       15195  female                     1
# 17719       15471  female                     1
# 17767       15520  female                     1
# 17821       14569  female                     1
# 17892       12713  female                     1
#
# [2875 rows x 3 columns]

# %%
male1 = gender_hypo1[gender_hypo1["gender"]=='male']
male1
# Out:
#       customer_id gender  customer_order_count
# 13          17809   male                    12
# 15          16098   male                     8
# 17          17420   male                     3
# 25          13408   male                    62
# 32          15862   male                     4
# ...           ...    ...                   ...
# 17617       12442   male                     1
# 17699       14087   male                     1
# 17714       14204   male                     1
# 17764       13436   male                     1
# 17801       13298   male                     1
#
# [1409 rows x 3 columns]

# %%
female1.customer_order_count.mean()
# Out:
# 4.134260869565217

# %%
male1.customer_order_count.mean()
# Out:
# 4.269694819020582

# %%
#Perform Levene test for equal variances
#H0: The population variances are equal
#H1: There is a difference between the variances in the population
#The small p-value suggests that the populations do not have equal variances.
#The large p-value suggests that the populations have equal variances.
leveneTest = stats.levene(female1.customer_order_count, male1.customer_order_count)
leveneTest
# Out:
# LeveneResult(statistic=0.42560598599645894, pvalue=0.5141879570448049)

# %% [raw]
# The Levene Test suggests that the two populations have equal variances.

# %%
indTest = stats.ttest_ind(female1.customer_order_count, male1.customer_order_count, equal_var=True)
indTest
# Out:
# TtestResult(statistic=-0.5729999193842997, pvalue=0.5666748357113767, df=4282.0)

# %%
alpha = 0.05

if indTest.pvalue < alpha:
    print('At {} level of significance, we can reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print("At {} level of significance, we fail to reject the null hypothesis. We don't have strong evidence to reject the null hypothesis.".format(alpha))
# Out:
# At 0.05 level of significance, we fail to reject the null hypothesis. We don't have strong evidence to reject the null hypothesis.

# %% [raw]
# Conclusion : There appears to be no statistically significant difference between males and females in their purchasing behavior measured as number of orders.

# %% [markdown]
# ### b) Is there a difference between males and females in order total amount?

# %% [raw]
# # State the null and alternative hypotheses
# H0: mu1 = mu2
#
# H1: mu1 != mu2

# %%
gender_revenue = df2[['customer_id','gender', 'customer_revenue']].drop_duplicates()

# %%
gender_revenue
# Out:
#       customer_id  gender  customer_revenue
# 0           17850  female           5391.21
# 2           13047  female           3214.74
# 4           12583  female           7281.38
# 5           13748  female            948.25
# 8           15100  female            876.00
# ...           ...     ...               ...
# 17764       13436    male            196.89
# 17767       15520  female            343.50
# 17801       13298    male            360.00
# 17821       14569  female            227.39
# 17892       12713  female            848.55
#
# [4284 rows x 3 columns]

# %%
gender_revenue.gender.value_counts()
# Out:
# gender
# female    2875
# male      1409
# Name: count, dtype: Int64

# %%
female_revenue = gender_revenue[gender_revenue["gender"]=='female']
female_revenue
# Out:
#       customer_id  gender  customer_revenue
# 0           17850  female           5391.21
# 2           13047  female           3214.74
# 4           12583  female           7281.38
# 5           13748  female            948.25
# 8           15100  female            876.00
# ...           ...     ...               ...
# 17692       15195  female           3861.00
# 17719       15471  female            469.48
# 17767       15520  female            343.50
# 17821       14569  female            227.39
# 17892       12713  female            848.55
#
# [2875 rows x 3 columns]

# %%
male_revenue = gender_revenue[gender_revenue["gender"]=='male']
male_revenue
# Out:
#       customer_id gender  customer_revenue
# 13          17809   male           5411.91
# 15          16098   male           2163.53
# 17          17420   male            598.83
# 25          13408   male          28117.04
# 32          15862   male            832.88
# ...           ...    ...               ...
# 17617       12442   male            172.06
# 17699       14087   male            194.42
# 17714       14204   male            161.03
# 17764       13436   male            196.89
# 17801       13298   male            360.00
#
# [1409 rows x 3 columns]

# %%
female_revenue.customer_revenue.mean()
# Out:
# 1800.6291140869564

# %%
male_revenue.customer_revenue.mean()
# Out:
# 1743.9676508161817

# %%
#Perform Levene test for equal variances
#H0: The population variances are equal
#H1: There is a difference between the variances in the population
#The small p-value suggests that the populations do not have equal variances.
#The large p-value suggests that the populations have equal variances.
leveneTest = stats.levene(np.log(female_revenue.customer_revenue), np.log(male_revenue.customer_revenue))
leveneTest
# Out:
# LeveneResult(statistic=1.2257100959834843, pvalue=0.26830513575528514)

# %% [raw]
# The Levene Test suggests that the two populations have equal variances.

# %%
indTest = stats.ttest_ind(np.log(female_revenue.customer_revenue), np.log(male_revenue.customer_revenue), equal_var=True)
indTest
# Out:
# TtestResult(statistic=0.0028145584473102518, pvalue=0.9977544413434398, df=4282.0)

# %%
alpha = 0.05

if indTest.pvalue < alpha:
    print('At {} level of significance, we can reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print("At {} level of significance, we fail to reject the null hypothesis. We don't have strong evidence to reject the null hypothesis.".format(alpha))
# Out:
# At 0.05 level of significance, we fail to reject the null hypothesis. We don't have strong evidence to reject the null hypothesis.

# %% [raw]
# Conclusion : There appears to be no statistically significant difference between males and females in their purchasing behavior measured as order total amount.

# %% [markdown]
# ### 2. Is there a relationship betweeen customer income and spending? Does customer spending increase with customer income?
#
# Statistical Method : correlation

# %%
df2
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 0     2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1     2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2     2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3     2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4     2010-12-01 08:45:00     536370       12583   59  female  40350.231046
# ...                   ...        ...         ...  ...     ...           ...
# 17897 2011-12-09 12:23:00     581583       13777   40  female  32712.707784
# 17898 2011-12-09 12:25:00     581584       13777   40  female  32712.707784
# 17899 2011-12-09 12:31:00     581585       15804   30  female  33151.297921
# 17900 2011-12-09 12:49:00     581586       13113   34  female  33687.081490
# 17901 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %%
income_revenue_corr = df2[['customer_id','income', 'customer_revenue']].drop_duplicates()

# %%
income_revenue_corr
# Out:
#       customer_id        income  customer_revenue
# 0           17850  26300.794657           5391.21
# 2           13047  40881.687219           3214.74
# 4           12583  40350.231046           7281.38
# 5           13748  33900.230649            948.25
# 8           15100  33418.281336            876.00
# ...           ...           ...               ...
# 17764       13436  21635.171374            196.89
# 17767       15520  33180.212068            343.50
# 17801       13298  32030.441561            360.00
# 17821       14569  43057.944411            227.39
# 17892       12713  33055.532352            848.55
#
# [4284 rows x 3 columns]

# %%
x = np.log(income_revenue_corr['income'])

# %%
y = np.log(income_revenue_corr['customer_revenue'])

# %%
income_revenue_corr['income'].corr(income_revenue_corr['customer_revenue'])
# Out:
# 0.011540990601104396

# %%
np.log(income_revenue_corr['income']).corr(np.log(income_revenue_corr['customer_revenue']))
# Out:
# 0.000313977292023101

# %%
from scipy.stats import pearsonr

correlation_coefficient, p_value = pearsonr(x, y)

print(f"Pearson Correlation Coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson Correlation Coefficient: 0.0003139772920230967
# P-value: 0.9836089891731098

# %% [raw]
# Conclusion : The obtained p-value of 0.984 is far greater than our chosen alpha level of 0.05. Therefore, we conclude that there is no statistically significant relationship between income and customer spending.
# The pearson correlation coefficient (0.0003) suggests that there is no correlation between income and customer spending.

# %% [markdown]
# ### Is there a relationship between age and shopping behavior in terms of:
#
# a) number of orders
#
# b) order total (revenue)?
#
# Statistical Method : correlation

# %% [markdown]
# #### a) Age and Number of Orders Placed

# %%
age_orders_corr = df2[['customer_id','age', 'customer_order_count']].drop_duplicates()
age_orders_corr
# Out:
#       customer_id  age  customer_order_count
# 0           17850   77                    34
# 2           13047   64                     8
# 4           12583   59                    15
# 5           13748   43                     5
# 8           15100   41                     3
# ...           ...  ...                   ...
# 17764       13436   21                     1
# 17767       15520   28                     1
# 17801       13298   31                     1
# 17821       14569   46                     1
# 17892       12713   34                     1
#
# [4284 rows x 3 columns]

# %%
x = age_orders_corr.age

# %%
y = age_orders_corr.customer_order_count

# %%
correlation_coefficient, p_value = pearsonr(x, y)

print(f"Pearson Correlation Coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson Correlation Coefficient: 0.0019890812593126466
# P-value: 0.8964461498364062

# %% [raw]
# Conclusion : The obtained p-value of 0.154 is far greater than our chosen alpha level of 0.05. Therefore, we conclude that there is no statistically significant relationship between age and number or orders.
# The pearson correlation coefficient (0.022) suggests that there is no correlation between age and number of orders.

# %% [markdown]
# #### b) Age and Customer Order Total

# %%
age_revenue_corr = df2[['customer_id','age', 'customer_revenue']].drop_duplicates()
age_revenue_corr
# Out:
#       customer_id  age  customer_revenue
# 0           17850   77           5391.21
# 2           13047   64           3214.74
# 4           12583   59           7281.38
# 5           13748   43            948.25
# 8           15100   41            876.00
# ...           ...  ...               ...
# 17764       13436   21            196.89
# 17767       15520   28            343.50
# 17801       13298   31            360.00
# 17821       14569   46            227.39
# 17892       12713   34            848.55
#
# [4284 rows x 3 columns]

# %%
x = age_revenue_corr.age

# %%
y = age_revenue_corr.customer_revenue

# %%
correlation_coefficient, p_value = pearsonr(x, y)

print(f"Pearson Correlation Coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson Correlation Coefficient: 0.021804417244538403
# P-value: 0.15360819766411307

# %% [raw]
# Conclusion : The obtained p-value of 0.154 is far greater than our chosen alpha level of 0.05. Therefore, we conclude that there is no statistically significant relationship between age and order total amount.
# The pearson correlation coefficient (0.002) suggests that there is no correlation between age and order total amount.

# %% [markdown]
# ### Does shopping behaviour vary with the day of the week in terms of:
#
# a) number of orders and
#
# b) total revenue?
#
# Statistical Method : ANOVA(F-test) and post-hoc Tukey test

# %%
df2
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 0     2010-12-01 08:26:00     536365       17850   77  female  26300.794657
# 1     2010-12-01 08:28:00     536366       17850   77  female  26300.794657
# 2     2010-12-01 08:34:00     536367       13047   64  female  40881.687219
# 3     2010-12-01 08:34:00     536368       13047   64  female  40881.687219
# 4     2010-12-01 08:45:00     536370       12583   59  female  40350.231046
# ...                   ...        ...         ...  ...     ...           ...
# 17897 2011-12-09 12:23:00     581583       13777   40  female  32712.707784
# 17898 2011-12-09 12:25:00     581584       13777   40  female  32712.707784
# 17899 2011-12-09 12:31:00     581585       15804   30  female  33151.297921
# 17900 2011-12-09 12:49:00     581586       13113   34  female  33687.081490
# 17901 2011-12-09 12:50:00     581587       12680   26    male  31414.340477
#
# ...

# %%
df2['day_of_week'] = df2['invoice_date'].dt.day_name()

# %%
df2['day_of_week'].value_counts()
# Out:
# day_of_week
# Thursday     3893
# Wednesday    3337
# Tuesday      3074
# Monday       2753
# Friday       2721
# Sunday       2124
# Name: count, dtype: int64

# %%
from scipy.stats import f_oneway

# %%
thursday = df2[df2['day_of_week']=='Thursday']
wednesday = df2[df2['day_of_week']=='Wednesday']
tuesday = df2[df2['day_of_week']=='Tuesday']
monday = df2[df2['day_of_week']=='Monday']
friday = df2[df2['day_of_week']=='Friday']
sunday = df2[df2['day_of_week']=='Sunday']

# %%
thursday
# Out:
#              invoice_date invoice_no customer_id  age  gender        income  \
# 117   2010-12-02 07:48:00     536598       13090   52    male  45430.982632
# 118   2010-12-02 07:49:00     536599       15694   61  female  39451.444345
# 119   2010-12-02 08:32:00     536600       17850   77  female  26300.794657
# 120   2010-12-02 08:33:00     536601       17850   77  female  26300.794657
# 121   2010-12-02 08:34:00     536602       17850   77  female  26300.794657
# ...                   ...        ...         ...  ...     ...           ...
# 17857 2011-12-08 19:28:00     581469       14606   28  female  31798.349432
# 17858 2011-12-08 19:29:00     581471       14702   42    male  32205.527201
# 17859 2011-12-08 19:55:00     581472       15796   52  female  43206.584171
# 17860 2011-12-08 19:57:00     581473       12748   29    male  31798.776856
# 17861 2011-12-08 20:01:00     581474       12748   29    male  31798.776856
#
# ...

# %%
sns.displot(x=df2["order_total_price"], kind="kde");

# %%
sns.displot(x=np.log(df2["order_total_price"]), kind="kde");

# %% [raw]
# # State the null and alternative hypotheses
#
# H0: mu1 = mu2 = mu3 = mu4 = mu5 = mu6
#
# H1: At least one of the must is different.

# %%
# run anova test

anova_test = f_oneway(np.log(monday.order_total_price),np.log(tuesday.order_total_price),np.log(wednesday.order_total_price),np.log(thursday.order_total_price),np.log(friday.order_total_price),np.log(sunday.order_total_price) )
anova_test
# Out:
# F_onewayResult(statistic=4.27161117595801, pvalue=0.0006964116476705964)

# %% [raw]
# We conclude that at least one mu is different.That is, customer spending appears to differ by day of week.
# Now we will run a post-hoc test to identify the days of week that differ from others pairwise.

# %%
import statsmodels.api as sm

# %%
print(sm.stats.multicomp.pairwise_tukeyhsd (np.log(df2.order_total_price), df2.day_of_week))
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1    group2  meandiff p-adj   lower   upper  reject
# ---------------------------------------------------------
#   Friday    Monday   0.0508 0.3106 -0.0196  0.1212  False
#   Friday    Sunday  -0.0586 0.2305  -0.134  0.0168  False
#   Friday  Thursday   0.0077 0.9994 -0.0573  0.0728  False
#   Friday   Tuesday   0.0388 0.5907 -0.0298  0.1073  False
#   Friday Wednesday    0.024 0.9119 -0.0432  0.0913  False
#   Monday    Sunday  -0.1094 0.0005 -0.1847 -0.0342   True
#   Monday  Thursday  -0.0431  0.407 -0.1079  0.0218  False
#   Monday   Tuesday   -0.012 0.9961 -0.0804  0.0563  False
#   Monday Wednesday  -0.0268  0.866 -0.0938  0.0403  False
#   Sunday  Thursday   0.0664 0.0768 -0.0039  0.1366  False
#   Sunday   Tuesday   0.0974 0.0022  0.0239  0.1709   True
#   Sunday Wednesday   0.0827 0.0143  0.0104   0.155   True
# Thursday   Tuesday    0.031 0.7226 -0.0318  0.0939  False
# ...

# %%
df2.groupby('day_of_week')['order_total_price'].mean()
# Out:
# day_of_week
# Friday       429.550100
# Monday       448.421199
# Sunday       359.994751
# Thursday     430.066930
# Tuesday      437.321962
# Wednesday    433.785622
# Name: order_total_price, dtype: float64

# %% [raw]
# Interpretation:
# Given the post-hoc test and the table showing average order totals by day of week, we see that Sunday is the day on which customers tend to spend the least on average.
# Sunday sales differ significantly with those of Monday, Tuesday, and Wednesday.

# %% [markdown]
# <a id="5"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">5) RFM ANALYSIS<p>
#
# ![image.png](attachment:image.png)
#
# **Image credit:** [Retail Automata Analytics](https://www.retailreco.com/blog/rfm-analysis-for-customer-segmentation-in-ecommerce//)

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# **Our goal in this Notebook is to cluster the customers in our data set to:**<br>
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# **- RECENCY (R):** Time since last purchase<br>
# **- FREQUENCY (F):** Total number of purchases<br>
# **- MONETARY VALUE (M):** Total monetary value
#
#
#
#
# **Benefits of RFM Analysis**
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# **RFM Analysis answers the following questions:**<br>
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# <a id="5.1"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">5.1 - The Tasks in This Section<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>
#
# **📢 SPECIAL NOTE: 👉 At the part of RFM Analysis, you just take the customers in the UK into consideration.**
#
# **1.** Importing Related Libraries.<br>
# **2.** Reviewing "df_uk" DataFrame.<br>
# **3.** Create a reference date for the calculations.<br>
# **4.** Calculating Recency.<br>
# **5.** Calculating Frequency.<br>
# **6.** Calculating Monetary Values.<br>
# **7.** Creating RFM Table.<br>
#
# **📢 NOTE: If you want, you can create and follow your own framework/workflow.**

# %%
df3 = pd.read_csv("df_uk.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354345 entries, 0 to 354344
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   invoice_date                 354345 non-null  object
#  1   invoice_no                   354345 non-null  int64
#  2   stock_code                   354345 non-null  object
#  3   description                  354345 non-null  object
#  4   quantity                     354345 non-null  int64
#  5   unit_price                   354345 non-null  float64
#  6   customer_id                  354345 non-null  float64
#  7   age                          354345 non-null  int64
#  8   gender                       354345 non-null  object
#  9   income                       354345 non-null  float64
#  10  country                      354345 non-null  object
#  11  revenue                      354345 non-null  float64
# ...

# %%
df3.head()
# Out:
#           invoice_date  invoice_no stock_code  \
# 0  2010-12-01 08:26:00      536365     85123A
# 1  2010-12-01 08:26:00      536365      71053
# 2  2010-12-01 08:26:00      536365     84406B
# 3  2010-12-01 08:26:00      536365     84029G
# 4  2010-12-01 08:26:00      536365     84029E
#
#                            description  quantity  unit_price  customer_id  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55      17850.0
# 1                  WHITE METAL LANTERN         6        3.39      17850.0
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75      17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39      17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39      17850.0
#
#    age  gender        income  ... order_quantity  order_unique_items  \
# 0   77  female  26300.794657  ...             40                   7
# 1   77  female  26300.794657  ...             40                   7
# ...

# %%
df3.isna().sum()
# Out:
# invoice_date                   0
# invoice_no                     0
# stock_code                     0
# description                    0
# quantity                       0
# unit_price                     0
# customer_id                    0
# age                            0
# gender                         0
# income                         0
# country                        0
# revenue                        0
# order_quantity                 0
# order_unique_items             0
# order_revenue                  0
# customer_order_count           0
# customer_order_total           0
# country_order_total            0
# country_customer_count         0
# country_order_count            0
# customer_unique_items          0
# avg_order_value_by_customer    0
# dtype: int64

# %%
df3.invoice_date = df3.invoice_date.astype('datetime64[us]') # change dtype
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354345 entries, 0 to 354344
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   invoice_date                 354345 non-null  datetime64[us]
#  1   invoice_no                   354345 non-null  int64
#  2   stock_code                   354345 non-null  object
#  3   description                  354345 non-null  object
#  4   quantity                     354345 non-null  int64
#  5   unit_price                   354345 non-null  float64
#  6   customer_id                  354345 non-null  float64
#  7   age                          354345 non-null  int64
#  8   gender                       354345 non-null  object
#  9   income                       354345 non-null  float64
#  10  country                      354345 non-null  object
#  11  revenue                      354345 non-null  float64
# ...

# %%
#reference_date
df3['invoice_date'].max()
present = dt.datetime(2011,12,10) # REFERENCE DATE 
df3["customer_id"] = df3["customer_id"].astype('Int64') # change dtype

# %%
# recency calc
rfm = df3.groupby('customer_id').agg({'invoice_date': lambda date: (present - date.max()).days,
                                        'invoice_no': lambda num: len(num),
                                        'revenue': lambda revenue: revenue.sum()})

# %%
rfm.reset_index(inplace=True)

# %%
rfm
# Out:
#       customer_id  invoice_date  invoice_no   revenue
# 0           12346           325           1  77183.60
# 1           12747             2         103   4196.01
# 2           12748             0        4596  33719.73
# 3           12749             3         199   4090.88
# 4           12820             3          59    942.34
# ...           ...           ...         ...       ...
# 3916        18280           277          10    180.60
# 3917        18281           180           7     80.82
# 3918        18282             7          12    178.05
# 3919        18283             3         756   2094.88
# 3920        18287            42          70   1837.28
#
# [3921 rows x 4 columns]

# %%
rfm.rename(columns={"invoice_date": "recency", "invoice_no": "frequency", "revenue": "monetary"}, inplace=True)

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  3921 non-null   Int64
#  1   recency      3921 non-null   int64
#  2   frequency    3921 non-null   int64
#  3   monetary     3921 non-null   float64
# dtypes: Int64(1), float64(1), int64(2)
# memory usage: 126.5 KB

# %%
rfm.customer_id = rfm.customer_id.astype('string')

# %% [markdown]
# <a id="6"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">6 - CUSTOMER SEGMENTATION WITH RFM SCORES</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# <a id="6.1"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">6.1 - Calculating RFM Scoring<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the customer_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %%
# clustering recency, frequency and monetary
rfm['r_quartile'] = pd.qcut(rfm['recency'], 4, ['4','3','2','1']) # the biggest value the best dvalue
rfm['f_quartile'] = pd.qcut(rfm['frequency'], 4, ['1','2','3','4']) # the biggest the best
rfm['m_quartile'] = pd.qcut(rfm['monetary'], 4, ['1','2','3','4']) # the biggest the best

# %%
#double-check
rfm[rfm["customer_id"] == "16422"] # caseo maxima
# Out:
#      customer_id  recency  frequency  monetary r_quartile f_quartile  \
# 2581       16422       17        369   34684.4          4          4
#
#      m_quartile
# 2581          4

# %%
#combine to a single string
rfm['rfm_score'] = rfm.r_quartile.astype(str)+ rfm.f_quartile.astype(str) + rfm.m_quartile.astype(str)
rfm.head()
# Out:
#   customer_id  recency  frequency  monetary r_quartile f_quartile m_quartile  \
# 0       12346      325          1  77183.60          1          1          4
# 1       12747        2        103   4196.01          4          4          4
# 2       12748        0       4596  33719.73          4          4          4
# 3       12749        3        199   4090.88          4          4          4
# 4       12820        3         59    942.34          4          3          3
#
#   rfm_score
# 0       114
# 1       444
# 2       444
# 3       444
# 4       433

# %%
#sort
rfm.sort_values('rfm_score', ascending=False)
# Out:
#      customer_id  recency  frequency  monetary r_quartile f_quartile  \
# 2870       16813        8        449   1692.98          4          4
# 3429       17611        7        576   3984.22          4          4
# 1547       15023        3        562   6802.76          4          4
# 325        13269        1        316   5346.23          4          4
# 324        13268       17        440   3214.69          4          4
# ...          ...      ...        ...       ...        ...        ...
# 1672       15180      367          6     87.50          1          1
# 1670       15178      260          3     40.50          1          1
# 349        13302      155          1     63.75          1          1
# 614        13682      187          3     59.50          1          1
# 900        14090      324          1     76.32          1          1
#
#      m_quartile rfm_score
# 2870          4       444
# 3429          4       444
# 1547          4       444
# 325           4       444
# ...

# %%
#sum of integer values
rfm['rfm_score_total'] = rfm.r_quartile.astype(int)+ rfm.f_quartile.astype(int) + rfm.m_quartile.astype(int)
rfm.head()
# Out:
#   customer_id  recency  frequency  monetary r_quartile f_quartile m_quartile  \
# 0       12346      325          1  77183.60          1          1          4
# 1       12747        2        103   4196.01          4          4          4
# 2       12748        0       4596  33719.73          4          4          4
# 3       12749        3        199   4090.88          4          4          4
# 4       12820        3         59    942.34          4          3          3
#
#   rfm_score  rfm_score_total
# 0       114                6
# 1       444               12
# 2       444               12
# 3       444               12
# 4       433               10

# %%
#sort
rfm.sort_values('rfm_score_total', ascending=False)
# Out:
#      customer_id  recency  frequency  monetary r_quartile f_quartile  \
# 1053       14309        8        117   2352.53          4          4
# 3578       17811        4        851   7837.73          4          4
# 1646       15144        8        217   6580.44          4          4
# 1652       15150       17        343   5314.47          4          4
# 1653       15152        9        271   4745.69          4          4
# ...          ...      ...        ...       ...        ...        ...
# 1570       15049      273          3    121.17          1          1
# 530        13561      215         14    141.86          1          1
# 1563       15042      199          5    135.93          1          1
# 2567       16403      312         10    177.50          1          1
# 3453       17643      373          8    101.55          1          1
#
#      m_quartile rfm_score  rfm_score_total
# 1053          4       444               12
# 3578          4       444               12
# ...

# %%
rfm.r_quartile = rfm.r_quartile.astype(float)
rfm.f_quartile = rfm.f_quartile.astype(float)
rfm.m_quartile = rfm.m_quartile.astype(float)

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3921 entries, 0 to 3920
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      3921 non-null   string
#  1   recency          3921 non-null   int64
#  2   frequency        3921 non-null   int64
#  3   monetary         3921 non-null   float64
#  4   r_quartile       3921 non-null   float64
#  5   f_quartile       3921 non-null   float64
#  6   m_quartile       3921 non-null   float64
#  7   rfm_score        3921 non-null   object
#  8   rfm_score_total  3921 non-null   int32
# dtypes: float64(4), int32(1), int64(2), object(1), string(1)
# memory usage: 260.5+ KB

# %%
# Define segmentation function
def segment_customer(row):
    y_axis = (row['f_quartile'] + row['m_quartile'])
    if row['r_quartile'] == 4 and y_axis >= 6 :
        return 'Champions'
    elif row['r_quartile'] >= 3  and (y_axis >= 4 and y_axis < 6):
        return 'Potential Loyalists'
    elif row['r_quartile'] == 4 and y_axis < 4 :
        return 'New Comers'
    elif (row['r_quartile'] == 2 or row['r_quartile'] == 3) and y_axis >= 6:
        return 'Loyal Customers'
    elif row['r_quartile'] == 2 and (y_axis >= 4 and y_axis < 6):
        return 'About to Sleep'
    elif row['r_quartile'] == 2 and y_axis < 4 :
        return 'Need Attention'
    elif row['r_quartile'] == 3 and y_axis < 4 :
        return 'Promising'
    elif row['r_quartile'] == 1 and y_axis >= 6 :
        return 'Can\'t Lose Them'
    elif row['r_quartile'] == 1 and (y_axis >= 4 and y_axis < 6) :
        return 'At Risk'
    elif row['r_quartile'] == 1 and y_axis < 4 :
        return 'Hibernating'
    # Add more conditions as needed
    else:
        return 'None'

# Apply the segmentation function to create a new 'segmentation' column
rfm['segmentation'] = rfm.apply(segment_customer, axis=1)

# hibernating bölümü vakit oldukça 2ye bölünebilir. (lost customer ve hibernating)

# %%
rfm
# Out:
#      customer_id  recency  frequency  monetary  r_quartile  f_quartile  \
# 0          12346      325          1  77183.60         1.0         1.0
# 1          12747        2        103   4196.01         4.0         4.0
# 2          12748        0       4596  33719.73         4.0         4.0
# 3          12749        3        199   4090.88         4.0         4.0
# 4          12820        3         59    942.34         4.0         3.0
# ...          ...      ...        ...       ...         ...         ...
# 3916       18280      277         10    180.60         1.0         1.0
# 3917       18281      180          7     80.82         1.0         1.0
# 3918       18282        7         12    178.05         4.0         1.0
# 3919       18283        3        756   2094.88         4.0         4.0
# 3920       18287       42         70   1837.28         3.0         3.0
#
#       m_quartile rfm_score  rfm_score_total     segmentation
# ...

# %%
# Calculate mean and count
agg_df = rfm.groupby('segmentation').agg({
    'recency': 'mean',
    'frequency': 'mean',
    'monetary': ['mean', 'count']
}).round(1)
# Rename columns for clarity
agg_df.columns = ['Recency (Mean)', 'Frequency (Mean)', 'Monetary (Mean)', 'Count']
# Calculate the percentage column
total_count = agg_df['Count'].sum()
agg_df['Percentage'] = (agg_df['Count'] / total_count * 100).round(2)
# Sort by count in descending order
agg_df = agg_df.sort_values('Count', ascending=False)
# Display the resulting DataFrame
agg_df
# Out:
#                      Recency (Mean)  Frequency (Mean)  Monetary (Mean)  Count  \
# segmentation
# Loyal Customers                51.3             127.7           2196.8    859
# Champions                       7.4             248.5           5502.7    726
# Hibernating                   255.7              11.6            203.1    537
# Potential Loyalists            22.8              38.3           1025.5    442
# At Risk                       241.4              34.3           1011.2    329
# About to Sleep                 84.2              33.2            682.0    328
# Need Attention                 85.9              11.9            239.6    289
# Promising                      32.9              14.5            218.0    197
# Can't Lose Them               208.5             100.3           1530.7    113
# New Comers                      9.6              12.7            222.7    101
#
#                      Percentage
# segmentation
# Loyal Customers           21.91
# ...

# %% [markdown]
# <a id="6.2"></a>
# ### <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:LEFT; border-radius:10px 10px;">6.2 - Plotting RFM Segments<p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %%
# Çubuk grafik oluşturun
sns.barplot(x=rfm['segmentation'].value_counts().index, y=rfm['segmentation'].value_counts().values)
plt.xticks(rotation=90)

# Grafik üzerine annotasyon ekleyin
ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='baseline')

# Ekseni daha iyi görünmesi için düzenleyin (isteğe bağlı)
plt.xlabel('Segmentation')
plt.ylabel('Count')
plt.title('Segmentation Distribution')

# Grafiği görüntüleyin
plt.show()

# %%
# Prepare data for the treemap (replace rfm with your DataFrame)
segment_count = rfm['segmentation'].value_counts()
total_count = segment_count.sum()
segment_percentage = (segment_count / total_count) * 100
# Combine count and percentage data
treemap_data = pd.DataFrame({'count': segment_count, 'percentage': segment_percentage}).reset_index()
treemap_data.columns = ['Segmentation', 'Count', 'Percentage']
# Create the treemap
fig, ax = plt.subplots(figsize=(12, 8))
# Plot the treemap with borders
squarify.plot(sizes=treemap_data['Count'], label=treemap_data['Segmentation'], alpha=.8, edgecolor='black')
# Annotate each segment
for i, (rect, (count, percentage)) in enumerate(zip(ax.patches, zip(treemap_data['Count'], treemap_data['Percentage']))):
    x, y, dx, dy = rect.get_x(), rect.get_y(), rect.get_width(), rect.get_height()
    ax.text(x + dx/2.15 - 4, y + dy/2.15 - 4, f"Count: {count}\nPercentage: {percentage:.2f}%",
            ha='left', va='center', fontsize=8, bbox=dict(facecolor='white', alpha=0.5))
plt.title('Customer Segmentation Treemap')
plt.axis('off')
plt.show()

# %%
sns.scatterplot(data=rfm, x='recency', y='frequency', hue='segmentation');

# %%
#sns.set_theme(style="ticks")
#sns.pairplot(rfm, hue="segmentation")

# %% [markdown]
# <a id="7"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">7 - CREATING COHORTS & CONDUCTING COHORT ANALYSIS</p>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %%
df3.head(1)
# Out:
#          invoice_date  invoice_no stock_code  \
# 0 2010-12-01 08:26:00      536365     85123A
#
#                           description  quantity  unit_price  customer_id  age  \
# 0  WHITE HANGING HEART T-LIGHT HOLDER         6        2.55        17850   77
#
#    gender        income  ... order_quantity  order_unique_items  \
# 0  female  26300.794657  ...             40                   7
#
#    order_revenue  customer_order_count  customer_order_total  \
# 0         139.12                    34               5391.21
#
#    country_order_total  country_customer_count  country_order_count  \
# 0          7308391.554                    3921                16649
#
#    customer_unique_items  avg_order_value_by_customer
# 0                     21                      158.565
#
# [1 rows x 22 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354345 entries, 0 to 354344
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   invoice_date                 354345 non-null  datetime64[us]
#  1   invoice_no                   354345 non-null  int64
#  2   stock_code                   354345 non-null  object
#  3   description                  354345 non-null  object
#  4   quantity                     354345 non-null  int64
#  5   unit_price                   354345 non-null  float64
#  6   customer_id                  354345 non-null  Int64
#  7   age                          354345 non-null  int64
#  8   gender                       354345 non-null  object
#  9   income                       354345 non-null  float64
#  10  country                      354345 non-null  object
#  11  revenue                      354345 non-null  float64
# ...

# %%
# cohort analizde kullanılmayacak sütunlar drop edildi
df3.drop(columns=["age", "gender","description", "income"], inplace=True)

# %%
#drop işlemi sonrası kontrol 
df.head(1)
# Out:
#          invoice_date invoice_no customer_id  age  gender        income  \
# 0 2010-12-01 08:26:00     536365       17850   77  female  26300.794657
#
#           country  order_unique_items  order_total_quantity  order_total_price
# 0  United Kingdom                   7                    40             139.12

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354345 entries, 0 to 354344
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   invoice_date                 354345 non-null  datetime64[us]
#  1   invoice_no                   354345 non-null  int64
#  2   stock_code                   354345 non-null  object
#  3   quantity                     354345 non-null  int64
#  4   unit_price                   354345 non-null  float64
#  5   customer_id                  354345 non-null  Int64
#  6   country                      354345 non-null  object
#  7   revenue                      354345 non-null  float64
#  8   order_quantity               354345 non-null  int64
#  9   order_unique_items           354345 non-null  int64
#  10  order_revenue                354345 non-null  float64
#  11  customer_order_count         354345 non-null  int64
# ...

# %%
#create a new column called invoice month
df3['invoice_month'] = df3['invoice_date'].apply(lambda x: dt.datetime(x.year, x.month, 1))

# %%
df3["invoice_month"].value_counts()
# Out:
# invoice_month
# 2011-11-01    58809
# 2011-10-01    43735
# 2011-09-01    35636
# 2011-05-01    25203
# 2011-03-01    24014
# 2010-12-01    23943
# 2011-06-01    23714
# 2011-07-01    23599
# 2011-08-01    23105
# 2011-04-01    20866
# 2011-01-01    18161
# 2011-02-01    17759
# 2011-12-01    15801
# Name: count, dtype: int64

# %%
# create a column index with the minimum invoice month
df3["cohort_month"] = df3.groupby("customer_id")["invoice_month"].transform("min")

# %%
df3[df3["customer_id"] == 14040.0]
# Out:
#               invoice_date  invoice_no stock_code  quantity  unit_price  \
# 30491  2011-01-12 14:57:00      540975      22710        25        0.42
# 30492  2011-01-12 14:57:00      540975      22660         2        7.95
# 30493  2011-01-12 14:57:00      540975      22692         2        7.95
# 30494  2011-01-12 14:57:00      540975      48188         2        7.95
# 30495  2011-01-12 14:57:00      540975      48187         3        7.95
# ...                    ...         ...        ...       ...         ...
# 247424 2011-10-09 13:58:00      570232      23424         2        4.95
# 276521 2011-10-30 12:42:00      573354      20725        50        1.65
# 276522 2011-10-30 12:42:00      573354     85099B        10        2.08
# 276523 2011-10-30 12:42:00      573354      23133         2        8.25
# 276524 2011-10-30 12:42:00      573354      84946        17        1.25
#
#         customer_id         country  revenue  order_quantity  \
# ...

# %%
#create a date element function to get a series for substraction
def get_date_int(df, column):
    year = df[column].dt.year
    month = df[column].dt.month
    day = df[column].dt.day
    return year, month, day

# %%
invoice_year, invoice_month, _   = get_date_int(df3, "invoice_month")
cohort_year, cohort_month, _ = get_date_int(df3, "cohort_month")

# %%
invoice_year.value_counts()
# Out:
# invoice_month
# 2011    330402
# 2010     23943
# Name: count, dtype: int64

# %%
invoice_month.value_counts()
# Out:
# invoice_month
# 11    58809
# 10    43735
# 12    39744
# 9     35636
# 5     25203
# 3     24014
# 6     23714
# 7     23599
# 8     23105
# 4     20866
# 1     18161
# 2     17759
# Name: count, dtype: int64

# %%
year_diff = invoice_year - cohort_year
month_diff = invoice_month - cohort_month

# %%
df3["cohort_index"] = year_diff * 12 + month_diff + 1

# %%
df3.sample(5)
# Out:
#               invoice_date  invoice_no stock_code  quantity  unit_price  \
# 235301 2011-09-30 12:03:00      569089      23202         4        2.08
# 101785 2011-04-26 09:37:00      551002      84879        16        1.69
# 103467 2011-04-27 13:44:00      551282     84596G         8        0.42
# 290428 2011-11-07 11:32:00      574836      22594        12        0.85
# 19745  2010-12-15 15:14:00      539040      22079         5        1.65
#
#         customer_id         country  revenue  order_quantity  \
# 235301        13764  United Kingdom     8.32             342
# 101785        16834  United Kingdom    27.04             358
# 103467        16919  United Kingdom     3.36             116
# 290428        17623  United Kingdom    10.20             265
# 19745         17214  United Kingdom     8.25              43
#
#         order_unique_items  ...  customer_order_count  customer_order_total  \
# 235301                  70  ...                     3               1521.76
# ...

# %%
# count the customer_id by cohort month and cohort index
df3.groupby(["cohort_month", "cohort_index"])["customer_id"].apply(pd.Series.unique)
# Out:
# cohort_month  cohort_index
# 2010-12-01    1               [17850, 13047, 13748, 15100, 15291, 14688, 178...
#               2               [18097, 16656, 13094, 17315, 16255, 14606, 133...
#               3               [14496, 17675, 17511, 15039, 18055, 17884, 146...
#               4               [13880, 17068, 12971, 15194, 18044, 18075, 153...
#               5               [13694, 13758, 15018, 13468, 18118, 17288, 179...
#                                                     ...
# 2011-10-01    2               [13755, 16747, 14102, 17086, 14815, 15814, 148...
#               3               [15993, 16513, 12912, 17321, 17014, 15948, 173...
# 2011-11-01    1               [13697, 14345, 17503, 16830, 17495, 14485, 138...
#               2               [13040, 16376, 15060, 14216, 12950, 15531, 175...
# 2011-12-01    1               [14804, 15904, 16789, 17942, 13560, 15539, 130...
# Name: customer_id, Length: 91, dtype: object

# %%
df3.groupby(["cohort_month", "cohort_index"])["customer_id"].apply(pd.Series.nunique)
# Out:
# cohort_month  cohort_index
# 2010-12-01    1               815
#               2               289
#               3               263
#               4               304
#               5               293
#                              ...
# 2011-10-01    2                79
#               3                36
# 2011-11-01    1               298
#               2                35
# 2011-12-01    1                34
# Name: customer_id, Length: 91, dtype: int64

# %%
cohort_df = df3.groupby(["cohort_month", "cohort_index"])["customer_id"].apply(pd.Series.nunique).reset_index()
cohort_df
# Out:
#    cohort_month  cohort_index  customer_id
# 0    2010-12-01             1          815
# 1    2010-12-01             2          289
# 2    2010-12-01             3          263
# 3    2010-12-01             4          304
# 4    2010-12-01             5          293
# ..          ...           ...          ...
# 86   2011-10-01             2           79
# 87   2011-10-01             3           36
# 88   2011-11-01             1          298
# 89   2011-11-01             2           35
# 90   2011-12-01             1           34
#
# [91 rows x 3 columns]

# %%
cohort_df[cohort_df["cohort_month"] == "2011-12-01"]
# Out:
#    cohort_month  cohort_index  customer_id
# 90   2011-12-01             1           34

# %%
# create a pivot table with cohort month as index and cohort index as columns
cohort_pivot = cohort_df.pivot_table(index = "cohort_month", columns = "cohort_index", values = "customer_id")
cohort_pivot
# Out:
# cohort_index     1      2      3      4      5      6      7      8      9   \
# cohort_month
# 2010-12-01    815.0  289.0  263.0  304.0  293.0  323.0  291.0  278.0  289.0
# 2011-01-01    358.0   76.0   93.0   84.0  119.0   99.0   90.0   87.0  108.0
# 2011-02-01    340.0   64.0   66.0   97.0   98.0   86.0   87.0   96.0   90.0
# 2011-03-01    419.0   64.0  109.0   83.0   94.0   69.0  111.0   96.0  119.0
# 2011-04-01    277.0   58.0   56.0   60.0   56.0   61.0   61.0   73.0   20.0
# 2011-05-01    256.0   48.0   44.0   44.0   53.0   58.0   68.0   23.0    NaN
# 2011-06-01    214.0   38.0   31.0   51.0   51.0   69.0   21.0    NaN    NaN
# 2011-07-01    169.0   30.0   33.0   39.0   47.0   18.0    NaN    NaN    NaN
# 2011-08-01    141.0   32.0   32.0   34.0   17.0    NaN    NaN    NaN    NaN
# 2011-09-01    276.0   63.0   83.0   32.0    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    324.0   79.0   36.0    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
new_cohort_pivot = cohort_pivot.divide(cohort_pivot.iloc[:, 0], axis = 0).round(3)
new_cohort_pivot
# Out:
# cohort_index   1      2      3      4      5      6      7      8      9   \
# cohort_month
# 2010-12-01    1.0  0.355  0.323  0.373  0.360  0.396  0.357  0.341  0.355
# 2011-01-01    1.0  0.212  0.260  0.235  0.332  0.277  0.251  0.243  0.302
# 2011-02-01    1.0  0.188  0.194  0.285  0.288  0.253  0.256  0.282  0.265
# 2011-03-01    1.0  0.153  0.260  0.198  0.224  0.165  0.265  0.229  0.284
# 2011-04-01    1.0  0.209  0.202  0.217  0.202  0.220  0.220  0.264  0.072
# 2011-05-01    1.0  0.188  0.172  0.172  0.207  0.227  0.266  0.090    NaN
# 2011-06-01    1.0  0.178  0.145  0.238  0.238  0.322  0.098    NaN    NaN
# 2011-07-01    1.0  0.178  0.195  0.231  0.278  0.107    NaN    NaN    NaN
# 2011-08-01    1.0  0.227  0.227  0.241  0.121    NaN    NaN    NaN    NaN
# 2011-09-01    1.0  0.228  0.301  0.116    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    1.0  0.244  0.111    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
#change index
new_cohort_pivot.index = new_cohort_pivot.index.strftime('%B %Y')

# %%
#create a percentage pivot table
plt.figure(figsize = (15, 8))
sns.heatmap(new_cohort_pivot, annot = True, fmt='.1%')
# Out:
# <Axes: xlabel='cohort_index', ylabel='cohort_month'>

# %%
# calculate the average quantity by cohort month and cohort index
avg_quantity = df3.groupby(["cohort_month", "cohort_index"])["quantity"].mean().reset_index()
avg_quantity
# Out:
#    cohort_month  cohort_index   quantity
# 0    2010-12-01             1  11.183686
# 1    2010-12-01             2  12.775966
# 2    2010-12-01             3  13.801289
# 3    2010-12-01             4  13.708637
# 4    2010-12-01             5  13.214496
# ..          ...           ...        ...
# 86   2011-10-01             2   7.108652
# 87   2011-10-01             3   8.048689
# 88   2011-11-01             1   8.781862
# 89   2011-11-01             2   9.280961
# 90   2011-12-01             1  15.302817
#
# [91 rows x 3 columns]

# %%
avg_quantity_pivot = avg_quantity.pivot_table(index = "cohort_month", columns = "cohort_index", values = "quantity")

# %%
avg_quantity_pivot.index = avg_quantity_pivot.index.strftime('%B %Y')

# %%
avg_quantity_pivot
# Out:
# cohort_index           1          2          3          4          5   \
# cohort_month
# December 2010   11.183686  12.775966  13.801289  13.708637  13.214496
# January 2011    17.802107   9.511542   9.376795  14.950188  10.039773
# February 2011   10.895653  13.823124  15.984066  12.058874  12.264347
# March 2011       9.633389  11.371037  13.259289  10.053191  14.111845
# April 2011      10.011642  10.129032   9.716430  11.915186  11.692956
# May 2011        10.537754   9.267337  14.670543  12.800244  10.966332
# June 2011        9.461976  14.559364  11.894942  12.608802   9.687421
# July 2011       10.053388  14.984576   6.483376   8.012156   5.690634
# August 2011      9.335191   6.003876   5.002608   5.912797   6.558894
# September 2011  11.848113   6.050224   7.770174   8.968937        NaN
# October 2011     8.565114   7.108652   8.048689        NaN        NaN
# November 2011    8.781862   9.280961        NaN        NaN        NaN
# ...

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(avg_quantity_pivot, annot = True, fmt='.1f')
# Out:
# <Axes: xlabel='cohort_index', ylabel='cohort_month'>

# %%
revenue_df = df3.groupby(["cohort_month", "cohort_index"])["revenue"].apply(sum).reset_index()
revenue_df
# Out:
#    cohort_month  cohort_index    revenue
# 0    2010-12-01             1  498661.85
# 1    2010-12-01             2  199589.91
# 2    2010-12-01             3  184212.54
# 3    2010-12-01             4  231642.70
# 4    2010-12-01             5  177150.26
# ..          ...           ...        ...
# 86   2011-10-01             2   38149.20
# 87   2011-10-01             3   10864.26
# 88   2011-11-01             1  118930.50
# 89   2011-11-01             2   13847.68
# 90   2011-12-01             1   24460.56
#
# [91 rows x 3 columns]

# %%
revenue_df_pivot = revenue_df.pivot_table(index = "cohort_month", columns = "cohort_index", values = "revenue")
revenue_df_pivot
# Out:
# cohort_index          1          2          3          4          5   \
# cohort_month
# 2010-12-01    498661.850  199589.91  184212.54  231642.70  177150.26
# 2011-01-01    242600.150   35383.79   39333.93   59385.42   58518.88
# 2011-02-01    136059.300   25911.59   34920.00   44006.41   38694.62
# 2011-03-01    170310.370   27854.07   57311.43   38039.09   46743.76
# 2011-04-01    110249.391   26076.38   23069.73   23047.18   24585.19
# 2011-05-01     95050.180   16689.83   16827.45   17302.21   25919.35
# 2011-06-01    107586.470   12220.92   10008.52   20094.33   20965.63
# 2011-07-01     61486.571    9600.26   11905.64   15669.40   15218.08
# 2011-08-01     56678.820   20056.65   32223.91   41416.68   14238.44
# 2011-09-01    137458.601   25247.48   34138.94   11628.27        NaN
# 2011-10-01    139623.370   38149.20   10864.26        NaN        NaN
# 2011-11-01    118930.500   13847.68        NaN        NaN        NaN
# ...

# %%
new_revenue_df_pivot = revenue_df_pivot.divide(revenue_df_pivot.iloc[:, 0], axis = 0).round(3)
new_revenue_df_pivot
# Out:
# cohort_index   1      2      3      4      5      6      7      8      9   \
# cohort_month
# 2010-12-01    1.0  0.400  0.369  0.465  0.355  0.543  0.502  0.476  0.522
# 2011-01-01    1.0  0.146  0.162  0.245  0.241  0.208  0.235  0.177  0.249
# 2011-02-01    1.0  0.190  0.257  0.323  0.284  0.227  0.310  0.422  0.374
# 2011-03-01    1.0  0.164  0.337  0.223  0.274  0.205  0.333  0.369  0.393
# 2011-04-01    1.0  0.237  0.209  0.209  0.223  0.227  0.245  0.282  0.049
# 2011-05-01    1.0  0.176  0.177  0.182  0.273  0.266  0.293  1.862    NaN
# 2011-06-01    1.0  0.114  0.093  0.187  0.195  0.276  0.071    NaN    NaN
# 2011-07-01    1.0  0.156  0.194  0.255  0.248  0.070    NaN    NaN    NaN
# 2011-08-01    1.0  0.354  0.569  0.731  0.251    NaN    NaN    NaN    NaN
# 2011-09-01    1.0  0.184  0.248  0.085    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    1.0  0.273  0.078    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
new_revenue_df_pivot.index = new_revenue_df_pivot.index.strftime('%B %Y')

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(new_revenue_df_pivot, annot = True, fmt='.1%')
# Out:
# <Axes: xlabel='cohort_index', ylabel='cohort_month'>

# %%
df3.head(1)
# Out:
#          invoice_date  invoice_no stock_code  quantity  unit_price  \
# 0 2010-12-01 08:26:00      536365     85123A         6        2.55
#
#    customer_id         country  revenue  order_quantity  order_unique_items  \
# 0        17850  United Kingdom     15.3              40                   7
#
#    ...  customer_order_count  customer_order_total  country_order_total  \
# 0  ...                    34               5391.21          7308391.554
#
#    country_customer_count  country_order_count  customer_unique_items  \
# 0                    3921                16649                     21
#
#    avg_order_value_by_customer  invoice_month cohort_month cohort_index
# 0                      158.565     2010-12-01   2010-12-01            1
#
# [1 rows x 21 columns]

# %%
invoice_no_df = df3.groupby(["cohort_month", "cohort_index"])["invoice_no"].apply(pd.Series.nunique).reset_index()
invoice_no_df
# Out:
#    cohort_month  cohort_index  invoice_no
# 0    2010-12-01             1        1291
# 1    2010-12-01             2         470
# 2    2010-12-01             3         421
# 3    2010-12-01             4         514
# 4    2010-12-01             5         464
# ..          ...           ...         ...
# 86   2011-10-01             2         125
# 87   2011-10-01             3          45
# 88   2011-11-01             1         368
# 89   2011-11-01             2          41
# 90   2011-12-01             1          36
#
# [91 rows x 3 columns]

# %%
invoice_no_df_pivot = invoice_no_df.pivot_table(index = "cohort_month", columns = "cohort_index", values = "invoice_no")
invoice_no_df_pivot
# Out:
# cohort_index      1      2      3      4      5      6      7      8      9   \
# cohort_month
# 2010-12-01    1291.0  470.0  421.0  514.0  464.0  582.0  509.0  485.0  481.0
# 2011-01-01     404.0   98.0  124.0  111.0  165.0  137.0  129.0  118.0  141.0
# 2011-02-01     378.0   79.0   89.0  133.0  119.0  109.0  101.0  129.0  113.0
# 2011-03-01     460.0   83.0  147.0  116.0  114.0   91.0  134.0  129.0  185.0
# 2011-04-01     311.0   83.0   65.0   68.0   64.0   65.0   66.0   94.0   20.0
# 2011-05-01     293.0   65.0   54.0   57.0   76.0   70.0   94.0   26.0    NaN
# 2011-06-01     238.0   48.0   37.0   65.0   64.0  101.0   25.0    NaN    NaN
# 2011-07-01     193.0   31.0   44.0   45.0   66.0   19.0    NaN    NaN    NaN
# 2011-08-01     153.0   38.0   45.0   46.0   18.0    NaN    NaN    NaN    NaN
# 2011-09-01     310.0   84.0  118.0   36.0    NaN    NaN    NaN    NaN    NaN
# 2011-10-01     383.0  125.0   45.0    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
new_invoice_no_df_pivot = invoice_no_df_pivot.divide(invoice_no_df_pivot.iloc[:, 0], axis = 0).round(3)
new_invoice_no_df_pivot
# Out:
# cohort_index   1      2      3      4      5      6      7      8      9   \
# cohort_month
# 2010-12-01    1.0  0.364  0.326  0.398  0.359  0.451  0.394  0.376  0.373
# 2011-01-01    1.0  0.243  0.307  0.275  0.408  0.339  0.319  0.292  0.349
# 2011-02-01    1.0  0.209  0.235  0.352  0.315  0.288  0.267  0.341  0.299
# 2011-03-01    1.0  0.180  0.320  0.252  0.248  0.198  0.291  0.280  0.402
# 2011-04-01    1.0  0.267  0.209  0.219  0.206  0.209  0.212  0.302  0.064
# 2011-05-01    1.0  0.222  0.184  0.195  0.259  0.239  0.321  0.089    NaN
# 2011-06-01    1.0  0.202  0.155  0.273  0.269  0.424  0.105    NaN    NaN
# 2011-07-01    1.0  0.161  0.228  0.233  0.342  0.098    NaN    NaN    NaN
# 2011-08-01    1.0  0.248  0.294  0.301  0.118    NaN    NaN    NaN    NaN
# 2011-09-01    1.0  0.271  0.381  0.116    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    1.0  0.326  0.117    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
invoice_no_df_pivot.index = invoice_no_df_pivot.index.strftime('%B %Y')
plt.figure(figsize = (15, 8))
sns.heatmap(invoice_no_df_pivot, annot = True, fmt='.1f');

# %%
df3['customer_type'] = np.where(df3['cohort_index'] == 1, 'new customer', 'existing customer')

# %%
df3
# Out:
#               invoice_date  invoice_no stock_code  quantity  unit_price  \
# 0      2010-12-01 08:26:00      536365     85123A         6        2.55
# 1      2010-12-01 08:26:00      536365      71053         6        3.39
# 2      2010-12-01 08:26:00      536365     84406B         8        2.75
# 3      2010-12-01 08:26:00      536365     84029G         6        3.39
# 4      2010-12-01 08:26:00      536365     84029E         6        3.39
# ...                    ...         ...        ...       ...         ...
# 354340 2011-12-09 12:31:00      581585      22466        12        1.95
# 354341 2011-12-09 12:49:00      581586      22061         8        2.95
# 354342 2011-12-09 12:49:00      581586      23275        24        1.25
# 354343 2011-12-09 12:49:00      581586      21217        24        8.95
# 354344 2011-12-09 12:49:00      581586      20685        10        7.08
#
#         customer_id         country  revenue  order_quantity  \
# ...

# %%
df3[df3["customer_id"] == 15804	]
# Out:
#               invoice_date  invoice_no stock_code  quantity  unit_price  \
# 126339 2011-05-25 10:12:00      554557      22178        12        1.25
# 126340 2011-05-25 10:12:00      554557     84970L        12        0.95
# 126341 2011-05-25 10:12:00      554557      84978        12        1.25
# 126342 2011-05-25 10:12:00      554557      21682         4        4.95
# 126343 2011-05-25 10:12:00      554557      21683         6        2.95
# ...                    ...         ...        ...       ...         ...
# 354336 2011-12-09 12:31:00      581585      21684        12        0.85
# 354337 2011-12-09 12:31:00      581585      22398        12        0.39
# 354338 2011-12-09 12:31:00      581585      23328         4        3.75
# 354339 2011-12-09 12:31:00      581585      23145        12        0.95
# 354340 2011-12-09 12:31:00      581585      22466        12        1.95
#
#         customer_id         country  revenue  order_quantity  \
# ...

# %%
df3[df3["customer_id"] == 15804	].value_counts()
# Out:
# invoice_date         invoice_no  stock_code  quantity  unit_price  customer_id  country         revenue  order_quantity  order_unique_items  order_revenue  customer_order_count  customer_order_total  country_order_total  country_customer_count  country_order_count  customer_unique_items  avg_order_value_by_customer  invoice_month  cohort_month  cohort_index  customer_type
# 2011-05-25 10:12:00  554557      15034       24        0.14        15804        United Kingdom  3.36     314             34                  525.36         13                    4206.39               7308391.554          3921                    16649                170                    323.568462                   2011-05-01     2011-05-01    1             new customer         1
# ...

# %%
# total revenue per customer
df3['customer_revenue'] = df3.groupby('customer_id')['revenue'].transform('sum')

# %%
df4 = df3[["customer_id", "invoice_month","customer_type", "customer_revenue"]].drop_duplicates()

# %%
df4
# Out:
#         customer_id invoice_month      customer_type  customer_revenue
# 0             17850    2010-12-01       new customer           5391.21
# 9             13047    2010-12-01       new customer           3237.54
# 26            13748    2010-12-01       new customer            948.25
# 45            15100    2010-12-01       new customer            876.00
# 62            15291    2010-12-01       new customer           4668.30
# ...             ...           ...                ...               ...
# 354146        14446    2011-12-01  existing customer           1039.58
# 354253        16705    2011-12-01  existing customer          14034.99
# 354257        17581    2011-12-01  existing customer          11045.04
# 354320        15804    2011-12-01  existing customer           4206.39
# 354341        13113    2011-12-01  existing customer          12245.96
#
# [11791 rows x 4 columns]

# %%
df4
# Out:
#         customer_id invoice_month      customer_type  customer_revenue
# 0             17850    2010-12-01       new customer           5391.21
# 9             13047    2010-12-01       new customer           3237.54
# 26            13748    2010-12-01       new customer            948.25
# 45            15100    2010-12-01       new customer            876.00
# 62            15291    2010-12-01       new customer           4668.30
# ...             ...           ...                ...               ...
# 354146        14446    2011-12-01  existing customer           1039.58
# 354253        16705    2011-12-01  existing customer          14034.99
# 354257        17581    2011-12-01  existing customer          11045.04
# 354320        15804    2011-12-01  existing customer           4206.39
# 354341        13113    2011-12-01  existing customer          12245.96
#
# [11791 rows x 4 columns]

# %%
# Format 'invoice_month' as year-month string
df4['invoice_month'] = df4['invoice_month'].dt.strftime('%Y-%m')
# Group the DataFrame by 'invoice_month' and 'customer_type' and calculate the total revenue for each group
pivot_df2 = df4.pivot_table(index='invoice_month', columns='customer_type', values='customer_id', aggfunc='count')
pivot_df2= pivot_df2.fillna(0)
# Calculate the total revenue for each 'invoice_month'
total_revenue = pivot_df2.sum(axis=1)
# Calculate the percentage of "existing customers" within each 'invoice_month'
percentage_existing_customers = (pivot_df2['existing customer'] / total_revenue) * 100
# Create a stacked bar chart
ax = pivot_df2.plot(kind='bar', stacked=True, figsize=(20, 6))
# Add percentage annotations for "existing customers" on top of the bars
for idx, month in enumerate(pivot_df2.index):
    percentage = percentage_existing_customers.loc[month]
    ax.annotate(f"{percentage:.2f}%", (idx, pivot_df2['existing customer'][month] + 5), ha='center', va='top')
# Set axis labels and title
plt.xlabel('Invoice Month')
plt.ylabel('Revenue')
plt.title('Revenue by Invoice Month')
# Show the legend
plt.legend(title='Customer Type')
# Show the plot
plt.show()

# %%
# Group the DataFrame by 'invoice_month' and 'customer_type' and calculate the total revenue for each group
pivot_df = df4.pivot_table(index='invoice_month', columns='customer_type', values='customer_revenue', aggfunc='sum')
# Calculate the total revenue for each 'invoice_month'
total_revenue = pivot_df.sum(axis=1)
# Calculate the percentage of "existing customers" within each 'invoice_month'
percentage_existing_customers = (pivot_df['existing customer'] / total_revenue) * 100
# Create a stacked bar chart
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(20, 6))
# Add percentage annotations for "existing customers" on top of the bars
for idx, month in enumerate(pivot_df.index):
    percentage = percentage_existing_customers.loc[month]
    ax.annotate(f"{percentage:.2f}%", (idx, pivot_df['existing customer'][month] + 5), ha='center', va='top')
# Set axis labels and title
plt.xlabel('Invoice Month')
plt.ylabel('Customer Revenue')
plt.title('Count of Customers by Month and Type')
# Show the legend
plt.legend(title='Customer Type')
# Show the plot
plt.show()

# %% [markdown]
# <a id="8"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">8 - CONCLUSION</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# 1.Objective of the Analysis
# The primary focus of our project was to gain actionable insights into customer behavior through Exploratory Data Analysis (EDA) and RFM Analysis.
# The goal was to segment customers effectively and understand their shopping patterns, thereby enabling targeted marketing and improving customer retention.
# To be honest, learning was and always will be G2's primary goal.
#
# 2.Data Preparation + EDA
# The initial dataset was subjected to encompassing cleaning and pre-processing steps.
# 2.1. We have standardized the titles of each attribute in the dataset (Skimpy)
# 2.2. Next, the missing values were handled (customer_id-based)
# 2.3. We have detected several invoice_no containing C which denotes 'Cancelled Orders'. Quantity was consistently negative when invoice_no starts with C. Therefore 'Cancelled Orders' were droppped.
# 2.4. Afterwards we have handled the data anomalies (unit_price being 0)
# 2.5. Dtypes were adjusted for the efficient usage (dtime, int, string, etc)
# 2.6. New featurtes were created (revenue = unit_price*quantity)
# 2.7 Order-based aggregate metrics were introduced (number of unique items per order, quantity per order, total revenue per order)
# 2.8. New dataframe was designed so that each invoice_no was a unique entry(df) by dropping the duplicate values after reducing the level of granularity and summing the metrics into new columns
# 2.9. Customer-level and country-based aggregates were calculated (customer_order_count, customer_revenue and country_order_count respectively)
#
# 3.Descriptive analysis
# 3.1.We have illustrated the customer-based and country-based metrics by adding descriptive graphs
# 3.2. Time-based revenue metrics were illustrated (revenue by week, revenue by month, number of orders by month)
# 3.3. Summary stats were illsutrated
#
# 4.Inferential analysis
# 4.1. Outliers were handled within the scope of the inferentual stats(z score > 3 was used).
# 4.2. New dataframe was designed (after dropping outliers based on age, income, order_total_price, order_total_quantity)
# 4.3. Same customer-based and country-based metrics were calculated (without outliers)
# 4.4. Hypothesis testing was conducted
# *Male vs Female (conclusion : There appears to be no statistically significant difference between males and females in their purchasing behavior measured as order total amount)
# *Income vs Spending
# *Age and Spending
# Conclusion : There appears to be no statistically significant relationship between the aforementioned variables
# 4.5. ANOVA (F-test) was conducted. Given the post-hoc test and the table showing average order totals by day of week, we see that Sunday is the day on which customers tend to spend the least on average.
# Sunday sales differ significantly less with those of Monday, Tuesday, and Wednesday.
#
# 5.RFM Analysis + RFM segmentation
# 5.1. Prepared the dataset for the RFM analysis (dtypes, UK dataset)
# 5.2. Set the reference date to (2011,12,10)
# 5.3. The RFM scoring was created (recency, frequency, monetary = rfm_score)
# 5.4. Segmentation was performed (each customer was assigned a respective label)
# 5.5. RFM segmentation was plotted (barchart, treemap, scatterplot)
#
# 6.COHORT analysis
# 6.1. The dataset for cohortt analysis was prepared(invoice_month = reference date, cohort_month = min cohort_month - first purchase)
# 6.2. The difference between the dates of each order and the first order over time is calculated
# 6.3. Cohort pivot_table was created (customer _id based, index + percentages growth over time) + the difference between each purchase and the first purchase (in months) was calculated
# e.g. Of 815 customers acquired in Dec 2010, 289 returned in Jan 2011 and so on...
# 2010-12-01	815.0	289.0	263.0	304.0	293.0	323.0	291.0	278.0	289.0	325.0	299.0
# 6.4. The cohort pivot_table was plotted (heatmap)
# 6.5. Quantity-based average cohort analysis was conducted and visualized
# 6.6. Revenue-based cohort analysis was conducted and visualized
# 6.7. Invoice number-based cohort analysis was conducted and visualized
# 6.8. Customer type column was added (new_customer, existing_customer)
# 6.9. The count of new and existing customer within cohort analysis was performed
# 6.10. The post-hoc revenue-based analysis was conducted to evaluate the cohort-based financial valueo of two categories (new and existing)
#
# 7.Key Findings
# 7.1. EDA: Our analysis revealed significant relationships number of orders per customer, total revenue per customer, UK-based customers rule this dataset, the time-based analysis has illustrated the dynamic nature of purchasing behavior
# 7.2. RFM Analysis: We identified key customer segments that are highly valuable. These segments exhibited high frequency and monetary value with low recency.
# 7.3. Cohort Analysis: In conclusion, our analysis indicates a positive trend in the number of customers, which has resulted in steady revenue growth over time. It is important to highlight that the majority of this increased revenue can be attributed to our existing customer base. This underscores the significance of nurturing and retaining our loyal customers as a primary driver of our financial success. While new customer acquisition remains valuable, the enduring support of our existing customers plays a pivotal role in our continued growth and stability.
#
# Actionable Insights
# The RFM segments can be targeted with specific marketing strategies. For example, 'Loyal" customers could be offered premium memberships, while 'Low Value' customers could be re-engaged with special offers. The EDA findings suggest that marketing strategies should be age-specific to be most effective.

# %% [markdown]
# <a id="9"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">9 - REFERENCES</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# - Kline, R.B. (2011). Principles and practice of structural equation modeling (5th ed., pp. 3-427). New York:The Guilford Press.
# - Edwards, A. (1976). An introduction to linear regression and correlation. W. H. Freeman
# - Everitt, B. S.; Skrondal, A. (2010), The Cambridge Dictionary of Statistics, Cambridge University Press.
# - [Python Feature Engineering Cookbook](https://www.amazon.com/Python-Feature-Engineering-Cookbook-transforming/dp/1789806313/ref=sr_1_1?dchild=1&keywords=feature+engineering+cookbook&qid=1627628487&s=books&sr=1-1)
# - [Feature Engineering Made Easy](https://www.amazon.com/Feature-Engineering-Made-Easy-Identify-ebook/dp/B077N6MK5W)
# - [Feature Engineering and Selection](https://www.amazon.com/Feature-Engineering-Selection-Chapman-Science/dp/1032090855/ref=sr_1_1?crid=19T9G95E1W7VJ&dchild=1&keywords=feature+engineering+and+selection+kuhn&qid=1628050948&sprefix=feature+engineering+and+%2Cdigital-text%2C293&sr=8-1)
# - [Introduction to Machine Learning with Python](https://www.amazon.com/Introduction-Machine-Learning-Python-Scientists/dp/1449369413)
# - [Neural Networks from Scratch in Python (by Kinsley § Kukiela)](https://nnfs.io/)
# - [Practical Statistics for Data Scientists (by Bruce & Gedeck)](https://www.amazon.com/Practical-Statistics-Data-Scientists-Essential/dp/149207294X/ref=sr_1_1?dchild=1&keywords=Practical+Statistics+for+Data+Scientists&qid=1627662007&sr=8-1)
# - [Applications of Deep Neural Networks(by Jeff Heaton)](https://arxiv.org/abs/2009.05673)
# - [Applied Predictive Modeling (by Kuhn & Johnson)](https://www.amazon.com/Applied-Predictive-Modeling-Max-Kuhn/dp/1461468485/ref=pd_sbs_3/141-4288971-3747365?pd_rd_w=AOIS7&pf_rd_p=3676f086-9496-4fd7-8490-77cf7f43f846&pf_rd_r=MCCHJXWK39VD6VW7RVAR&pd_rd_r=4ffcd1ea-44b9-4f33-b9b3-dc02ee159662&pd_rd_wg=nU1Ex&pd_rd_i=1461468485&psc=1:)
# - [Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow (by Aurélien Géron)](https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646/ref=sr_1_1?crid=2GV554Q2EKD1E&dchild=1&keywords=hands-on+machine+learning+with+scikit-learn%2C+keras%2C+and+tensorflow&qid=1627628294&s=books&sprefix=hands%2Cstripbooks-intl-ship%2C309&sr=1-1)
# - [Master Machine Learning Algorithms (by Brownlee, ML algorithms are very well explained)](https://machinelearningmastery.com/master-machine-learning-algorithms/)
# - [Python Feature Engineering Cookbook (by Galli)](https://www.amazon.com/Python-Feature-Engineering-Cookbook-transforming/dp/1789806313/ref=sr_1_1?dchild=1&keywords=feature+engineering+cookbook&qid=1627628487&s=books&sr=1-1)
# - [Feature Engineering Made Easy (by Ozdemir & Susarla)](https://www.amazon.com/Feature-Engineering-Made-Easy-Identify-ebook/dp/B077N6MK5W)
# - [Feature Engineering and Selection (by Kuhn & Johnson)](https://www.amazon.com/Feature-Engineering-Selection-Chapman-Science/dp/1032090855/ref=sr_1_1?crid=19T9G95E1W7VJ&dchild=1&keywords=feature+engineering+and+selection+kuhn&qid=1628050948&sprefix=feature+engineering+and+%2Cdigital-text%2C293&sr=8-1)
# - [Imbalanced Classification with Python(by Brownlee)](https://machinelearningmastery.com/imbalanced-classification-with-python/)
# - [Feature Engineering Made Easy](https://www.analyticsvidhya.com/blog/2021/06/generate-reports-using-pandas-profiling-deploy-using-streamlit/)
# - [Exploratory Data Analysis with Pandas Profiling](https://towardsdatascience.com/exploratory-data-analysis-with-pandas-profiling-de3aae2ddff3)
# - [Why Data Scaling is important in Machine Learning & How to effectively do it](https://analyticsindiamag.com/why-data-scaling-is-important-in-machine-learning-how-to-effectively-do-it/)
# - [Elbow Method for Finding the Optimal Number of Clusters in K-Means](https://www.analyticsvidhya.com/blog/2021/01/in-depth-intuition-of-k-means-clustering-algorithm-in-machine-learning/)
# - [Military Power Clustering](https://www.kaggle.com/kadirduran/military-power-clustering)
# - [Feature Engineering: Scaling, Normalization, and Standardization (Updated 2023)](https://www.analyticsvidhya.com/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/)
# - [How to use Data Scaling Improve Deep Learning Model Stability and Performance](https://machinelearningmastery.com/how-to-improve-neural-network-stability-and-modeling-performance-with-data-scaling/)
# - [Use Early Stopping to Halt the Training of Neural Networks At the Right Time](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/#:~:text=Early%20stopping%20is%20a%20method,deep%20learning%20neural%20network%20models.)
# - [Receiver Operating Characteristic Curve in Diagnostic Test Assessment](https://www.sciencedirect.com/science/article/pii/S1556086415306043)
# - [CRM Analizi (RFM Analizi ve CLTV (Müşteri Yaşam Boyu Değeri)) - In Turkish](https://medium.com/machine-learning-t%C3%BCrkiye/crm-analizi-rfm-analizi-ve-cltv-m%C3%BC%C5%9Fteri-ya%C5%9Fam-boyu-de%C4%9Feri-36e5c3a232b1)
# - [CRM Analizi (RFM Analizi ve CLTV (Müşteri Yaşam Boyu Değeri))](https://medium.com/capillary-data-science/rfm-analysis-an-effective-customer-segmentation-technique-using-python-58804480d232)
# - [RFM Analysis using BigQuery ML](https://towardsdatascience.com/rfm-analysis-using-bigquery-ml-bfaa51b83086)
# - [Kohort Analizi Hakkında Bilmeniz Gerekenler - In Turkish](https://www.ticimax.com/blog/kohort-analizi-hakkinda-bilmeniz-gerekenler)
# - [Online Retail Data Set](https://www.kaggle.com/vijayuv/onlineretail)
# - [RFM Analysis For Successful Customer Segmentation](https://www.putler.com/rfm-analysis/)
# - [RFM analysis for Customer Segmentation](https://clevertap.com/blog/rfm-analysis/)
# - [Understanding K-means Clustering in Machine Learning](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1)
# - [Selecting the number of clusters with silhouette analysis on KMeans clustering](https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)
# - [Selecting the number of clusters with silhouette analysis on KMeans clustering](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d)
# - [Feature engineering](https://en.wikipedia.org/wiki/Feature_engineering#:~:text=Feature%20engineering%20is%20the%20process,competitions%20and%20machine%20learning%20projects.)
# - [Fundamental Techniques of Feature Engineering for Machine Learning](https://towardsdatascience.com/feature-engineering-for-machine-learning-3a5e293a5114)
# - [Feature Engineering for Machine Learning: 10 Examples](https://www.kdnuggets.com/2018/12/feature-engineering-explained.html)
# - [Discover Feature Engineering, How to Engineer Features and How to Get Good at It](https://machinelearningmastery.com/discover-feature-engineering-how-to-engineer-features-and-how-to-get-good-at-it/)
# - [Step by Step process of Feature Engineering for Machine Learning Algorithms in Data Science](https://www.analyticsvidhya.com/blog/2021/03/step-by-step-process-of-feature-engineering-for-machine-learning-algorithms-in-data-science/)
# - [Cohort Analysis: Beginners Guide to Improving Retention](https://clevertap.com/blog/cohort-analysis/)

# %% [markdown]
# <a id="10"></a>
# ## <p style="background-color:#9452a5; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">10 - FURTHER READINGS</p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Table of Contents</a>

# %% [markdown]
# - Kline, R.B. (2011). Principles and practice of structural equation modeling (5th ed., pp. 3-427). New York:The Guilford Press.
# - Edwards, A. (1976). An introduction to linear regression and correlation. W. H. Freeman
# - Everitt, B. S.; Skrondal, A. (2010), The Cambridge Dictionary of Statistics, Cambridge University Press.
# - [Python Feature Engineering Cookbook](https://www.amazon.com/Python-Feature-Engineering-Cookbook-transforming/dp/1789806313/ref=sr_1_1?dchild=1&keywords=feature+engineering+cookbook&qid=1627628487&s=books&sr=1-1)
# - [Feature Engineering Made Easy](https://www.amazon.com/Feature-Engineering-Made-Easy-Identify-ebook/dp/B077N6MK5W)
# - [Feature Engineering and Selection](https://www.amazon.com/Feature-Engineering-Selection-Chapman-Science/dp/1032090855/ref=sr_1_1?crid=19T9G95E1W7VJ&dchild=1&keywords=feature+engineering+and+selection+kuhn&qid=1628050948&sprefix=feature+engineering+and+%2Cdigital-text%2C293&sr=8-1)
# - [Introduction to Machine Learning with Python](https://www.amazon.com/Introduction-Machine-Learning-Python-Scientists/dp/1449369413)
# - [Neural Networks from Scratch in Python (by Kinsley § Kukiela)](https://nnfs.io/)
# - [Practical Statistics for Data Scientists (by Bruce & Gedeck)](https://www.amazon.com/Practical-Statistics-Data-Scientists-Essential/dp/149207294X/ref=sr_1_1?dchild=1&keywords=Practical+Statistics+for+Data+Scientists&qid=1627662007&sr=8-1)
# - [Applications of Deep Neural Networks(by Jeff Heaton)](https://arxiv.org/abs/2009.05673)
# - [Applied Predictive Modeling (by Kuhn & Johnson)](https://www.amazon.com/Applied-Predictive-Modeling-Max-Kuhn/dp/1461468485/ref=pd_sbs_3/141-4288971-3747365?pd_rd_w=AOIS7&pf_rd_p=3676f086-9496-4fd7-8490-77cf7f43f846&pf_rd_r=MCCHJXWK39VD6VW7RVAR&pd_rd_r=4ffcd1ea-44b9-4f33-b9b3-dc02ee159662&pd_rd_wg=nU1Ex&pd_rd_i=1461468485&psc=1:)
# - [Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow (by Aurélien Géron)](https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646/ref=sr_1_1?crid=2GV554Q2EKD1E&dchild=1&keywords=hands-on+machine+learning+with+scikit-learn%2C+keras%2C+and+tensorflow&qid=1627628294&s=books&sprefix=hands%2Cstripbooks-intl-ship%2C309&sr=1-1)
# - [Master Machine Learning Algorithms (by Brownlee, ML algorithms are very well explained)](https://machinelearningmastery.com/master-machine-learning-algorithms/)
# - [Python Feature Engineering Cookbook (by Galli)](https://www.amazon.com/Python-Feature-Engineering-Cookbook-transforming/dp/1789806313/ref=sr_1_1?dchild=1&keywords=feature+engineering+cookbook&qid=1627628487&s=books&sr=1-1)
# - [Feature Engineering Made Easy (by Ozdemir & Susarla)](https://www.amazon.com/Feature-Engineering-Made-Easy-Identify-ebook/dp/B077N6MK5W)
# - [Feature Engineering and Selection (by Kuhn & Johnson)](https://www.amazon.com/Feature-Engineering-Selection-Chapman-Science/dp/1032090855/ref=sr_1_1?crid=19T9G95E1W7VJ&dchild=1&keywords=feature+engineering+and+selection+kuhn&qid=1628050948&sprefix=feature+engineering+and+%2Cdigital-text%2C293&sr=8-1)
# - [Imbalanced Classification with Python(by Brownlee)](https://machinelearningmastery.com/imbalanced-classification-with-python/)
# - [The Most Common EVALUATION METRICS- A Gentle Intro](https://www.kaggle.com/kaanboke/the-most-common-evaluation-metrics-a-gentle-intro)

# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>
